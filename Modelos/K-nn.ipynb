# %% [markdown]
# # K-Vizinhos Mais Próximos Classificador

# %% [markdown]
# ## Introdução

# %% [markdown]
# Este notebook visa fazer a otimização de **hiperparâmetros**, de estratégia de **normalização**, de **seleção de atributos** e de **redução de dimensionalidade**. A seleção de atributos é realizada por *Sequential Feature Selection* (**SFS**, ou Seleção Sequencial de Atributos em português) por remoção de atributo, a otimização testa a ausência ou não dessa estratégia. A redução de dimensionalidade é realizada por *Principal Component Analysis* (**PCA**, ou Análise de Componenetes Principais em português), é testada sua ausência também. Para normalização, são testadas a ausência, ou a normalização **padrão** ou a pelos **mínimos e máximos**. A otimização é feita usando o módulo **optuna**.

# %% [markdown]
# ### Modelo

# %% [markdown]
# O modelo otimizado é um K-nn classificador do scikit-learn [2]. Os hiperparâmetros otimizados são:
#
# - `n_neighbors`: número de vizinhos. Testados no **intervalo de 2 até 80**, que é um pouco mais de 10% dos 782 registros de tsunami;
#
# - `weights`: pesos no cálculo da moda entre os vizinhos mais próximos. Testado entre **'uniform'**, que dá o mesmo peso para todos os vizinhos, e **'distance'**, que dá mais peso aos vizinhos mais próximos;
#
# - `p`: potência minkowski. Testado no **intervalo entre 1 e 2**, sendo 1 a distância Manhattan e 2 a distância Euclidiana.

# %% [markdown]
# ## Carrega os dados

# %%
import pandas as pd

# Dados de treino
X_treino = pd.read_csv('../Dados/dados_tratados/X_treino.csv')
y_treino = pd.read_csv('../Dados/dados_tratados/y_treino.csv').values.ravel()

# %% [markdown]
# ## Define algumas variáveis úteis

# %%
from sklearn.metrics import fbeta_score, make_scorer

SEMENTE_ALEATORIA = 9 # Random state

f2_score = make_scorer(fbeta_score, beta=2) # Métrica de avaliação de desempenho
num_max_atributos = len(X_treino.columns) - 1 # Para SFS

X_treino = X_treino.values

# %% [markdown]
# ## Definição de funções para o optuna

# %% [markdown]
# O código abaixo define a função que cria uma instância do modelo. É nela que o pipeline é montado de acordo com as sugestões definidas pelo optuna.

# %%
from sklearn.neighbors import KNeighborsClassifier # algoritmo de aprendizado de máquina
from sklearn.preprocessing import StandardScaler, MinMaxScaler # normalização
from sklearn.feature_selection import SequentialFeatureSelector # seleção de atributos
from sklearn.decomposition import PCA # redução de dimensionalidade
from sklearn.pipeline import make_pipeline

def cria_instancia_modelo(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.

    """

    # trial.suggest_ do optuna
    
    # Hiperparâmetros do algoritmo
    parametros = {
        "n_neighbors": trial.suggest_int("vizinhos", 2, 80),
        "weights": trial.suggest_categorical("pesos", ["uniform", "distance"]), 
        "p": trial.suggest_float("p_minkowski", 1, 2), 
        "n_jobs": 1,
    }

    # Estratégias de tratamento de dados
    normalizacao = trial.suggest_categorical("normalizacao", ["none", "standard", "minmax"])
    usar_sfs = trial.suggest_categorical("SFS", [True, False])
    usar_pca = trial.suggest_categorical("PCA", [True, False])

    # Hiperparâmetros de SFS e PCA, respectivamente
    num_atributos = trial.suggest_int("num_atributos", 2, num_max_atributos) # para SFS
    num_dimensoes = trial.suggest_int("num_dimensoes", 2, num_atributos) # para PCA, depende do num_atributos do SFS
        
    # Monta o pipeline    
    
    steps = []

    # Normalização
    if normalizacao == "standard":
        steps.append(("normalizador", StandardScaler()))
    elif normalizacao == "minmax":
        steps.append(("normalizador", MinMaxScaler()))

    # SFS
    if usar_sfs:
        steps.append(("sfs", SequentialFeatureSelector(
            KNeighborsClassifier(**parametros), 
            n_features_to_select=num_atributos,
            direction="backward",
            scoring=f2_score,
            cv=5,
            n_jobs=1,
        )))

    # PCA
    if usar_pca:
        steps.append(("pca", PCA(n_components=num_dimensoes, random_state=SEMENTE_ALEATORIA)))

    steps.append(("modelo", KNeighborsClassifier(**parametros)))


    # Faz pipeline
    modelo = make_pipeline(*[s[1] for s in steps])

    return modelo

# %% [markdown]
# O código abaixo define a função que estima o desempenho do modelo de cada trial. Essa é a função que terá valor de retorno maximizado pelo optuna.

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

def funcao_objetivo(trial, X, y, num_folds):
    """Função objetivo do optuna, função cujo retorno será maximizado.

    Faz validação cruzada estratificada com métrica F2.

    Args:
        - trial: objeto tipo Trial do optuna;
        - x: ndarray. dataset de treino com atributos;
        - y: ndaray. dataset de treino com target;
        - num_folds: int. Número de folds da validação cruzada.
    
    Returns:
        - média dos resultados da validação cruzada.
    """
    modelo = cria_instancia_modelo(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring=f2_score,
        cv=num_folds,
    )

    return np.mean(metricas)

# %% [markdown]
# ## Otimização com optuna

# %% [markdown]
# O código abaixo cria ou carrega um 'estudo' a depender da existência dele. O 'estudo' contém informações sobre cada trial. A variável objeto_de_estudo acessa esse 'estudo'.

# %%
from optuna import create_study

NOME_DO_ESTUDO = "Knn_class_optuna"

objeto_de_estudo = create_study(
    direction="maximize",
    study_name=NOME_DO_ESTUDO,
    storage=f"sqlite:///{NOME_DO_ESTUDO}.db",
    load_if_exists=True,
)
# Out:
# [I 2025-10-31 20:07:14,494] Using an existing study with name 'Knn_class_optuna' instead of creating a new one.

# %% [markdown]
# O código abaixo faz a otimização com optuna.

# %%
# Parâmetros
NUM_FOLDS = 10 # Número de folds da validação cruzada
NUM_TENTATIVAS = 200 # Quantidade de trials

def funcao_objetivo_parcial(trial):
    '''Função objetivo no formato exigido pelo optuna.'''
    return funcao_objetivo(trial, X_treino, y_treino, NUM_FOLDS)

# Faz a otimização
objeto_de_estudo.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2025-10-30 18:54:56,331] Trial 1 finished with value: 0.8190777986823861 and parameters: {'vizinhos': 13, 'pesos': 'distance', 'p_minkowski': 1.5840645960411315, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 7, 'num_dimensoes': 4}. Best is trial 1 with value: 0.8190777986823861.
# [I 2025-10-30 18:54:57,124] Trial 2 finished with value: 0.8520135673325988 and parameters: {'vizinhos': 61, 'pesos': 'distance', 'p_minkowski': 1.7239051033127128, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 7, 'num_dimensoes': 3}. Best is trial 2 with value: 0.8520135673325988.
# [I 2025-10-30 18:55:10,671] Trial 3 finished with value: 0.67679520861162 and parameters: {'vizinhos': 68, 'pesos': 'distance', 'p_minkowski': 1.2659266615051732, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 3}. Best is trial 2 with value: 0.8520135673325988.
# [I 2025-10-30 18:55:12,228] Trial 4 finished with value: 0.7768684262306248 and parameters: {'vizinhos': 26, 'pesos': 'uniform', 'p_minkowski': 1.833746840098316, 'normalizacao': 'none', 'SFS': False, 'PCA': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8520135673325988.
# [I 2025-10-30 18:55:22,171] Trial 5 finished with value: 0.8570011160393648 and parameters: {'vizinhos': 19, 'pesos': 'uniform', 'p_minkowski': 1.6435715346017628, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 2}. Best is trial 5 with value: 0.8570011160393648.
# [I 2025-10-30 18:55:22,674] Trial 6 finished with value: 0.7745791245887957 and parameters: {'vizinhos': 29, 'pesos': 'distance', 'p_minkowski': 1.801776797648258, 'normalizacao': 'standard', 'SFS': False, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 5 with value: 0.8570011160393648.
# [I 2025-10-30 18:55:33,926] Trial 7 finished with value: 0.8709838841664608 and parameters: {'vizinhos': 77, 'pesos': 'distance', 'p_minkowski': 1.518008804427534, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 7 with value: 0.8709838841664608.
# [I 2025-10-30 18:55:49,186] Trial 8 finished with value: 0.8136240229262699 and parameters: {'vizinhos': 5, 'pesos': 'distance', 'p_minkowski': 1.8764464338377134, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 7 with value: 0.8709838841664608.
# [I 2025-10-30 18:55:58,693] Trial 9 finished with value: 0.8737168658999275 and parameters: {'vizinhos': 26, 'pesos': 'uniform', 'p_minkowski': 1.0914178027651333, 'normalizacao': 'none', 'SFS': True, 'PCA': False, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 9 with value: 0.8737168658999275.
# [I 2025-10-30 18:55:59,657] Trial 10 finished with value: 0.8331476796419901 and parameters: {'vizinhos': 36, 'pesos': 'distance', 'p_minkowski': 1.34860453678921, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 9 with value: 0.8737168658999275.
# [I 2025-10-30 18:56:18,989] Trial 11 finished with value: 0.8808927457533675 and parameters: {'vizinhos': 48, 'pesos': 'uniform', 'p_minkowski': 1.0872863834307567, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 11 with value: 0.8808927457533675.
# [I 2025-10-30 18:56:38,627] Trial 12 finished with value: 0.8820278668128122 and parameters: {'vizinhos': 51, 'pesos': 'uniform', 'p_minkowski': 1.0030686610505033, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 12 with value: 0.8820278668128122.
# [I 2025-10-30 18:56:59,487] Trial 13 finished with value: 0.8833687498431892 and parameters: {'vizinhos': 52, 'pesos': 'uniform', 'p_minkowski': 1.0107326858258097, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:57:19,726] Trial 14 finished with value: 0.8828876324323334 and parameters: {'vizinhos': 50, 'pesos': 'uniform', 'p_minkowski': 1.0019327224309633, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:57:39,462] Trial 15 finished with value: 0.8767111433394769 and parameters: {'vizinhos': 55, 'pesos': 'uniform', 'p_minkowski': 1.2653216162877545, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:57:59,290] Trial 16 finished with value: 0.8828148511537479 and parameters: {'vizinhos': 42, 'pesos': 'uniform', 'p_minkowski': 1.4089708717764435, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:58:21,702] Trial 17 finished with value: 0.8706774546658835 and parameters: {'vizinhos': 66, 'pesos': 'uniform', 'p_minkowski': 1.1829245921966907, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:58:38,856] Trial 18 finished with value: 0.8771956839927325 and parameters: {'vizinhos': 40, 'pesos': 'uniform', 'p_minkowski': 1.0039004794382351, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:58:39,359] Trial 19 finished with value: 0.8429670440341045 and parameters: {'vizinhos': 80, 'pesos': 'uniform', 'p_minkowski': 1.1748174082331013, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:58:58,295] Trial 20 finished with value: 0.8742422547238891 and parameters: {'vizinhos': 58, 'pesos': 'uniform', 'p_minkowski': 1.399974996420931, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:59:15,651] Trial 21 finished with value: 0.877152861108183 and parameters: {'vizinhos': 44, 'pesos': 'uniform', 'p_minkowski': 1.1267540844510955, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:59:35,435] Trial 22 finished with value: 0.8767340193782049 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.4306396617046553, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 18:59:56,402] Trial 23 finished with value: 0.8816218420063724 and parameters: {'vizinhos': 48, 'pesos': 'uniform', 'p_minkowski': 1.273323568425681, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:00:17,716] Trial 24 finished with value: 0.8829351113252436 and parameters: {'vizinhos': 41, 'pesos': 'uniform', 'p_minkowski': 1.0015155550097632, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:00:41,370] Trial 25 finished with value: 0.8732687303626131 and parameters: {'vizinhos': 67, 'pesos': 'uniform', 'p_minkowski': 1.0011584855361166, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:00:59,553] Trial 26 finished with value: 0.8760121570142916 and parameters: {'vizinhos': 34, 'pesos': 'uniform', 'p_minkowski': 1.0851965409910396, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:01:00,344] Trial 27 finished with value: 0.8184355260518748 and parameters: {'vizinhos': 54, 'pesos': 'uniform', 'p_minkowski': 1.973886888745082, 'normalizacao': 'minmax', 'SFS': False, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:01:19,753] Trial 28 finished with value: 0.8639157352514042 and parameters: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.193335214996527, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:01:41,618] Trial 29 finished with value: 0.8716317790903021 and parameters: {'vizinhos': 46, 'pesos': 'uniform', 'p_minkowski': 1.05901123269945, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:01:57,928] Trial 30 finished with value: 0.8678541701206173 and parameters: {'vizinhos': 15, 'pesos': 'uniform', 'p_minkowski': 1.1411550559858246, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:02:15,081] Trial 31 finished with value: 0.8091006604163276 and parameters: {'vizinhos': 74, 'pesos': 'uniform', 'p_minkowski': 1.5775265739530535, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:02:35,174] Trial 32 finished with value: 0.8828148511537479 and parameters: {'vizinhos': 41, 'pesos': 'uniform', 'p_minkowski': 1.3212087839631017, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:02:56,187] Trial 33 finished with value: 0.8828148511537479 and parameters: {'vizinhos': 42, 'pesos': 'uniform', 'p_minkowski': 1.2203039530615, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:03:17,374] Trial 34 finished with value: 0.8810185626580566 and parameters: {'vizinhos': 52, 'pesos': 'uniform', 'p_minkowski': 1.0498659960894865, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:03:17,973] Trial 35 finished with value: 0.8502426066683579 and parameters: {'vizinhos': 32, 'pesos': 'distance', 'p_minkowski': 1.6603716787810157, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:03:38,504] Trial 36 finished with value: 0.8613847190499436 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.116768679458997, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:03:54,969] Trial 37 finished with value: 0.8750083416360844 and parameters: {'vizinhos': 22, 'pesos': 'uniform', 'p_minkowski': 1.4280366381988263, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:03:56,932] Trial 38 finished with value: 0.8242220588810507 and parameters: {'vizinhos': 37, 'pesos': 'distance', 'p_minkowski': 1.5256957425113558, 'normalizacao': 'none', 'SFS': False, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:04:04,034] Trial 39 finished with value: 0.7765227300102464 and parameters: {'vizinhos': 49, 'pesos': 'uniform', 'p_minkowski': 1.7596203993725323, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 8, 'num_dimensoes': 8}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:04:16,804] Trial 40 finished with value: 0.850903056523974 and parameters: {'vizinhos': 30, 'pesos': 'distance', 'p_minkowski': 1.0465378391722497, 'normalizacao': 'none', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:04:37,164] Trial 41 finished with value: 0.8802713771874735 and parameters: {'vizinhos': 45, 'pesos': 'uniform', 'p_minkowski': 1.2291232631097542, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:04:56,862] Trial 42 finished with value: 0.8767340193782049 and parameters: {'vizinhos': 39, 'pesos': 'uniform', 'p_minkowski': 1.3924752724567293, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:05:17,076] Trial 43 finished with value: 0.8828148511537479 and parameters: {'vizinhos': 42, 'pesos': 'uniform', 'p_minkowski': 1.3423094206884902, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:05:38,439] Trial 44 finished with value: 0.863107753557564 and parameters: {'vizinhos': 57, 'pesos': 'uniform', 'p_minkowski': 1.3092354572963618, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 13 with value: 0.8833687498431892.
# [I 2025-10-30 19:05:56,930] Trial 45 finished with value: 0.8844804637138634 and parameters: {'vizinhos': 50, 'pesos': 'uniform', 'p_minkowski': 1.4602968650669246, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:06:17,542] Trial 46 finished with value: 0.8657057854431356 and parameters: {'vizinhos': 51, 'pesos': 'distance', 'p_minkowski': 1.4706261666059637, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:06:19,610] Trial 47 finished with value: 0.8176149019999407 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.5785897857577107, 'normalizacao': 'none', 'SFS': False, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:06:34,122] Trial 48 finished with value: 0.870434583038341 and parameters: {'vizinhos': 25, 'pesos': 'uniform', 'p_minkowski': 1.6789872567336634, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:06:53,315] Trial 49 finished with value: 0.8838742989406067 and parameters: {'vizinhos': 47, 'pesos': 'uniform', 'p_minkowski': 1.499394828977246, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:07:13,760] Trial 50 finished with value: 0.8629337986221083 and parameters: {'vizinhos': 72, 'pesos': 'uniform', 'p_minkowski': 1.8622697055717858, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:07:32,160] Trial 51 finished with value: 0.8829856474445462 and parameters: {'vizinhos': 54, 'pesos': 'distance', 'p_minkowski': 1.6066938408516946, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:07:49,650] Trial 52 finished with value: 0.8811079938500728 and parameters: {'vizinhos': 54, 'pesos': 'distance', 'p_minkowski': 1.7301692767712085, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 45 with value: 0.8844804637138634.
# [I 2025-10-30 19:08:06,914] Trial 53 finished with value: 0.8847395639841317 and parameters: {'vizinhos': 57, 'pesos': 'distance', 'p_minkowski': 1.6050194505346358, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:08:21,273] Trial 54 finished with value: 0.8788568266875206 and parameters: {'vizinhos': 57, 'pesos': 'distance', 'p_minkowski': 1.6253194563644886, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:08:37,325] Trial 55 finished with value: 0.8697662792281478 and parameters: {'vizinhos': 47, 'pesos': 'distance', 'p_minkowski': 1.5347765453934836, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:08:54,430] Trial 56 finished with value: 0.8750884576020358 and parameters: {'vizinhos': 63, 'pesos': 'distance', 'p_minkowski': 1.6047176602697373, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:09:04,510] Trial 57 finished with value: 0.8775683918227367 and parameters: {'vizinhos': 53, 'pesos': 'distance', 'p_minkowski': 1.485867382545512, 'normalizacao': 'none', 'SFS': True, 'PCA': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:09:05,450] Trial 58 finished with value: 0.8574203377596632 and parameters: {'vizinhos': 56, 'pesos': 'distance', 'p_minkowski': 1.6852039480907608, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:09:22,476] Trial 59 finished with value: 0.8791133426944701 and parameters: {'vizinhos': 60, 'pesos': 'distance', 'p_minkowski': 1.5618358915100503, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:09:40,129] Trial 60 finished with value: 0.8751014927759548 and parameters: {'vizinhos': 44, 'pesos': 'distance', 'p_minkowski': 1.4601744995293626, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:09:59,186] Trial 61 finished with value: 0.8342811927078417 and parameters: {'vizinhos': 70, 'pesos': 'distance', 'p_minkowski': 1.8080964520391976, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 53 with value: 0.8847395639841317.
# [I 2025-10-30 19:10:19,130] Trial 62 finished with value: 0.88563161013161 and parameters: {'vizinhos': 49, 'pesos': 'uniform', 'p_minkowski': 1.0469323587559685, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:10:37,032] Trial 63 finished with value: 0.8826215756290597 and parameters: {'vizinhos': 49, 'pesos': 'uniform', 'p_minkowski': 1.6369464050898679, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:10:55,189] Trial 64 finished with value: 0.8831651830154579 and parameters: {'vizinhos': 51, 'pesos': 'uniform', 'p_minkowski': 1.551042156487012, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:11:12,567] Trial 65 finished with value: 0.8811328264462466 and parameters: {'vizinhos': 51, 'pesos': 'distance', 'p_minkowski': 1.7099374506862879, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:11:31,446] Trial 66 finished with value: 0.8802480128423493 and parameters: {'vizinhos': 55, 'pesos': 'uniform', 'p_minkowski': 1.547584843064406, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:11:50,660] Trial 67 finished with value: 0.8815609520497303 and parameters: {'vizinhos': 46, 'pesos': 'uniform', 'p_minkowski': 1.4991787257617102, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:12:07,870] Trial 68 finished with value: 0.8676269426262954 and parameters: {'vizinhos': 58, 'pesos': 'uniform', 'p_minkowski': 1.5991710619554953, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:12:24,839] Trial 69 finished with value: 0.8708834541109521 and parameters: {'vizinhos': 62, 'pesos': 'uniform', 'p_minkowski': 1.9874675593086262, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:12:25,987] Trial 70 finished with value: 0.8515627940068431 and parameters: {'vizinhos': 52, 'pesos': 'distance', 'p_minkowski': 1.5125351664346047, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:12:41,566] Trial 71 finished with value: 0.8637101694628534 and parameters: {'vizinhos': 64, 'pesos': 'uniform', 'p_minkowski': 1.3826830961173973, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:13:02,177] Trial 72 finished with value: 0.878413893547503 and parameters: {'vizinhos': 48, 'pesos': 'uniform', 'p_minkowski': 1.0370811581245558, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19:13:10,565] Trial 73 finished with value: 0.8399513787207935 and parameters: {'vizinhos': 7, 'pesos': 'uniform', 'p_minkowski': 1.0868941763972604, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 62 with value: 0.88563161013161.
# [I 2025-10-30 19
 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:30:22,153] Trial 155 finished with value: 0.8861362212265222 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.1207503207965213, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:30:38,220] Trial 156 finished with value: 0.8094700776209421 and parameters: {'vizinhos': 32, 'pesos': 'uniform', 'p_minkowski': 1.072217980814562, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:30:47,242] Trial 157 finished with value: 0.8831526502304301 and parameters: {'vizinhos': 30, 'pesos': 'uniform', 'p_minkowski': 1.1429421012004202, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:30:56,639] Trial 158 finished with value: 0.88166138266159 and parameters: {'vizinhos': 33, 'pesos': 'uniform', 'p_minkowski': 1.0958740428765907, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:04,679] Trial 159 finished with value: 0.8816702830395726 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.0695342166805744, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:15,552] Trial 160 finished with value: 0.8800040019895196 and parameters: {'vizinhos': 34, 'pesos': 'uniform', 'p_minkowski': 1.1188936957933386, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:25,407] Trial 161 finished with value: 0.8825647926550936 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.085337652544119, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:36,139] Trial 162 finished with value: 0.8832164452460642 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0506451040555818, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:46,552] Trial 163 finished with value: 0.8776405539332892 and parameters: {'vizinhos': 31, 'pesos': 'uniform', 'p_minkowski': 1.0612694534902007, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:31:58,464] Trial 164 finished with value: 0.8861362212265222 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.0411862376550016, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:05,990] Trial 165 finished with value: 0.8785939622616314 and parameters: {'vizinhos': 33, 'pesos': 'uniform', 'p_minkowski': 1.13628701677839, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:17,017] Trial 166 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.1061037802690776, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:21,952] Trial 167 finished with value: 0.8434714704521292 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.1078305798520758, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 8, 'num_dimensoes': 7}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:33,686] Trial 168 finished with value: 0.8734031614868829 and parameters: {'vizinhos': 24, 'pesos': 'uniform', 'p_minkowski': 1.0961765234092755, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:44,623] Trial 169 finished with value: 0.8764695129314786 and parameters: {'vizinhos': 27, 'pesos': 'uniform', 'p_minkowski': 1.0763019417836532, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:32:54,587] Trial 170 finished with value: 0.8667498039514452 and parameters: {'vizinhos': 21, 'pesos': 'uniform', 'p_minkowski': 1.166675709334607, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:33:05,882] Trial 171 finished with value: 0.8867444937326049 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.1439480748167599, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:33:17,627] Trial 172 finished with value: 0.8867444937326049 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.1391112088737785, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:33:29,491] Trial 173 finished with value: 0.8842099649502433 and parameters: {'vizinhos': 33, 'pesos': 'uniform', 'p_minkowski': 1.1182321127351604, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:33:41,073] Trial 174 finished with value: 0.8825647926550936 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.088477864055324, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:33:52,225] Trial 175 finished with value: 0.8836361273451356 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0397961716404933, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:03,481] Trial 176 finished with value: 0.8776405539332892 and parameters: {'vizinhos': 31, 'pesos': 'uniform', 'p_minkowski': 1.0639044144547278, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:13,432] Trial 177 finished with value: 0.8792460660495227 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.1091912178166796, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:25,330] Trial 178 finished with value: 0.8800040019895196 and parameters: {'vizinhos': 34, 'pesos': 'uniform', 'p_minkowski': 1.1477466143588926, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:26,658] Trial 179 finished with value: 0.7711474571884571 and parameters: {'vizinhos': 32, 'pesos': 'uniform', 'p_minkowski': 1.1254487988189712, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:37,925] Trial 180 finished with value: 0.8768644638940829 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.0464432864967685, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:34:56,744] Trial 181 finished with value: 0.8206278213040024 and parameters: {'vizinhos': 41, 'pesos': 'uniform', 'p_minkowski': 1.075045832717387, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:35:08,216] Trial 182 finished with value: 0.8844290683887319 and parameters: {'vizinhos': 38, 'pesos': 'uniform', 'p_minkowski': 1.1339630238192613, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:35:19,579] Trial 183 finished with value: 0.8825647926550936 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.0956232236744872, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:35:29,423] Trial 184 finished with value: 0.8831557484618766 and parameters: {'vizinhos': 34, 'pesos': 'uniform', 'p_minkowski': 1.1763590336835685, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:35:37,430] Trial 185 finished with value: 0.8767777010062566 and parameters: {'vizinhos': 37, 'pesos': 'uniform', 'p_minkowski': 1.1405385890561262, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:35:51,723] Trial 186 finished with value: 0.8836361273451356 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0355001073957382, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:36:04,944] Trial 187 finished with value: 0.8795292770771465 and parameters: {'vizinhos': 29, 'pesos': 'uniform', 'p_minkowski': 1.0661780812985677, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:36:15,845] Trial 188 finished with value: 0.88166138266159 and parameters: {'vizinhos': 33, 'pesos': 'uniform', 'p_minkowski': 1.1072117604653267, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:36:25,602] Trial 189 finished with value: 0.8838381125819488 and parameters: {'vizinhos': 38, 'pesos': 'uniform', 'p_minkowski': 1.086488608895023, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:36:37,566] Trial 190 finished with value: 0.8848308198277884 and parameters: {'vizinhos': 41, 'pesos': 'uniform', 'p_minkowski': 1.0577282797232226, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:36:48,405] Trial 191 finished with value: 0.8756922083564621 and parameters: {'vizinhos': 32, 'pesos': 'uniform', 'p_minkowski': 1.123301721971326, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:00,427] Trial 192 finished with value: 0.8838381125819488 and parameters: {'vizinhos': 38, 'pesos': 'uniform', 'p_minkowski': 1.0367622502978513, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:12,004] Trial 193 finished with value: 0.8800646987737071 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.0566406156242008, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:24,564] Trial 194 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0914164358841496, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:36,036] Trial 195 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0879406804241667, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:48,266] Trial 196 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0873143159048637, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:37:59,901] Trial 197 finished with value: 0.8836361273451356 and parameters: {'vizinhos': 34, 'pesos': 'uniform', 'p_minkowski': 1.0797465344544066, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:38:09,435] Trial 198 finished with value: 0.874642952014824 and parameters: {'vizinhos': 31, 'pesos': 'uniform', 'p_minkowski': 1.099409217876857, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:38:20,685] Trial 199 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.080785507847872, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.
# [I 2025-10-30 19:38:31,747] Trial 200 finished with value: 0.8867878738174928 and parameters: {'vizinhos': 35, 'pesos': 'uniform', 'p_minkowski': 1.0808628242282565, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 75 with value: 0.8880490742005025.

# %% [markdown]
# ## DataFrame dos trials

# %% [markdown]
# O código abaixo mostra o DataFrame contruído pelo objeto de estudo do optuna contendo todos os parâmetros de cada trial.

# %%
df_analysis = objeto_de_estudo.trials_dataframe()

df_analysis
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0       NaN 2025-10-30 18:54:38.615988                        NaT
# 1         1  0.819078 2025-10-30 18:54:46.774941 2025-10-30 18:54:56.133398
# 2         2  0.852014 2025-10-30 18:54:56.342576 2025-10-30 18:54:57.037469
# 3         3  0.676795 2025-10-30 18:54:57.134654 2025-10-30 18:55:09.765389
# 4         4  0.776868 2025-10-30 18:55:10.683625 2025-10-30 18:55:12.115370
# ..      ...       ...                        ...                        ...
# 196     196  0.886788 2025-10-30 19:37:36.047430 2025-10-30 19:37:48.172381
# 197     197  0.883636 2025-10-30 19:37:48.278425 2025-10-30 19:37:59.576206
# 198     198  0.874643 2025-10-30 19:37:59.911588 2025-10-30 19:38:09.244795
# 199     199  0.886788 2025-10-30 19:38:09.445795 2025-10-30 19:38:20.662421
# 200     200  0.886788 2025-10-30 19:38:20.696012 2025-10-30 19:38:31.685603
#
#                   duration  params_PCA  params_SFS params_normalizacao  \
# 0                      NaT        True       False            standard
# 1   0 days 00:00:09.358457       False        True            standard
# 2   0 days 00:00:00.694893       False       False              minmax
# 3   0 days 00:00:12.630735        True        True            standard
# 4   0 days 00:00:01.431745       False       False                none
# ..                     ...         ...         ...                 ...
# 196 0 days 00:00:12.124951        True        True                none
# 197 0 days 00:00:11.297781        True        True                none
# 198 0 days 00:00:09.333207        True        True                none
# 199 0 days 00:00:11.216626        True        True                none
# 200 0 days 00:00:10.989591        True        True                none
#
#      params_num_atributos  params_num_dimensoes  params_p_minkowski  \
# 0                       3                     2            1.067813
# 1                       7                     4            1.584065
# 2                       7                     3            1.723905
# 3                       7                     3            1.265927
# 4                       8                     4            1.833747
# ..                    ...                   ...                 ...
# 196                     5                     3            1.087314
# 197                     5                     3            1.079747
# 198                     6                     3            1.099409
# 199                     5                     3            1.080786
# 200                     5                     3            1.080863
#
#     params_pesos  params_vizinhos     state
# 0        uniform               64   RUNNING
# 1       distance               13  COMPLETE
# 2       distance               61  COMPLETE
# 3       distance               68  COMPLETE
# 4        uniform               26  COMPLETE
# ..           ...              ...       ...
# 196      uniform               35  COMPLETE
# 197      uniform               34  COMPLETE
# 198      uniform               31  COMPLETE
# 199      uniform               35  COMPLETE
# 200      uniform               35  COMPLETE
#
# [201 rows x 14 columns]

# %% [markdown]
# ## Melhor modelo

# %% [markdown]
# O código abaixo mostra o melhor modelo encontrado pelo optuna e seus parâmetros. Note que os parâmetros 'num_atributos' e 'num_dimensoes' só influenciam caso 'SFS' e 'PCA' sejam True respectivamente, pois são seus respectivos hiperparâmetros.

# %%
melhor_trial = objeto_de_estudo.best_trial

print(f"Número do melhor trial: {melhor_trial.number}")
print(f"Parâmetros do melhor trial: {melhor_trial.params}")
# Out:
# Número do melhor trial: 75
# Parâmetros do melhor trial: {'vizinhos': 38, 'pesos': 'uniform', 'p_minkowski': 1.1213453726046692, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}

# %% [markdown]
# Este notebook se encerra aqui. O modelo será usado no notebook chamado 'Resultados_Discussão'.

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] Documentação do optuna. Acesso em: 31/10/2025. Disponível em: https://optuna.readthedocs.io/en/stable/
#
# [2] Página da Regressão Logística da documentação do scikit-learn. Acesso em: 31/10/2025. Disponível em: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression
#
# [3] Sperat, Walter. *Using optuna with sklearn the right way*. Acesso em 31/10/2025. Disponível em: https://medium.com/@walter_sperat/using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
