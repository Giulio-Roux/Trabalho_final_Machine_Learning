# %% [markdown]
# # K-Vizinhos Mais Próximos Classificador

# %% [markdown]
# ## Introdução

# %% [markdown]
# Este notebook visa fazer a otimização de **hiperparâmetros**, de estratégia de **normalização**, de **seleção de atributos** e de **redução de dimensionalidade**. A seleção de atributos é realizada por *Sequential Feature Selection* (**SFS**, ou Seleção Sequencial de Atributos em português) por remoção de atributo, a otimização testa a ausência ou não dessa estratégia. A redução de dimensionalidade é realizada por *Principal Component Analysis* (**PCA**, ou Análise de Componenetes Principais em português), é testada sua ausência também. Para normalização, são testadas a ausência, ou a normalização **padrão** ou a pelos **mínimos e máximos**. A otimização é feita usando o módulo **optuna**.

# %% [markdown]
# ### Modelo

# %% [markdown]
# O modelo otimizado é um K-nn classificador do scikit-learn [2]. Os hiperparâmetros otimizados são:
#
# - `n_neighbors`: número de vizinhos. Testados no **intervalo de 2 até 80**, que é um pouco mais de 10% dos 782 registros de tsunami;
#
# - `weights`: pesos no cálculo da moda entre os vizinhos mais próximos. Testado entre **'uniform'**, que dá o mesmo peso para todos os vizinhos, e **'distance'**, que dá mais peso aos vizinhos mais próximos;
#
# - `p`: potência minkowski. Testado no **intervalo entre 1 e 2**, sendo 1 a distância Manhattan e 2 a distância Euclidiana.

# %% [markdown]
# ## Carrega os dados

# %%
from pandas import read_csv

# Dados de treino
X_treino = read_csv('../Dados/dados_tratados/X_treino.csv')
y_treino = read_csv('../Dados/dados_tratados/y_treino.csv').values.ravel()

# %% [markdown]
# ## Define algumas variáveis úteis

# %%
from sklearn.metrics import fbeta_score, make_scorer

SEMENTE_ALEATORIA = 9 # Random state

f2_score = make_scorer(fbeta_score, beta=2) # Métrica de avaliação de desempenho
num_max_atributos = len(X_treino.columns) - 1 # Para SFS

X_treino = X_treino.values

# %% [markdown]
# ## Definição de funções para o optuna

# %% [markdown]
# O código abaixo define a função que cria uma instância do modelo. É nela que o pipeline é montado de acordo com as sugestões definidas pelo optuna.

# %%
from sklearn.neighbors import KNeighborsClassifier # algoritmo de aprendizado de máquina
from sklearn.preprocessing import StandardScaler, MinMaxScaler # normalização
from sklearn.feature_selection import SequentialFeatureSelector # seleção de atributos
from sklearn.decomposition import PCA # redução de dimensionalidade
from sklearn.pipeline import make_pipeline

def cria_instancia_modelo(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.

    """

    # trial.suggest_ do optuna
    
    # Hiperparâmetros do algoritmo
    parametros = {
        "n_neighbors": trial.suggest_int("vizinhos", 2, 80),
        "weights": trial.suggest_categorical("pesos", ["uniform", "distance"]), 
        "p": trial.suggest_float("p_minkowski", 1, 2), 
        "n_jobs": -1,
    }

    # Estratégias de tratamento de dados
    normalizacao = trial.suggest_categorical("normalizacao", ["none", "standard", "minmax"])
    usar_sfs = trial.suggest_categorical("SFS", [True, False])
    usar_pca = trial.suggest_categorical("PCA", [True, False])

    # Hiperparâmetros de SFS e PCA, respectivamente
    num_atributos = trial.suggest_int("num_atributos", 2, num_max_atributos) # para SFS
    num_dimensoes = trial.suggest_int("num_dimensoes", 2, num_atributos) # para PCA, depende do num_atributos do SFS
        
    # Monta o pipeline    
    
    steps = []

    # Normalização
    if normalizacao == "standard":
        steps.append(("normalizador", StandardScaler()))
    elif normalizacao == "minmax":
        steps.append(("normalizador", MinMaxScaler()))

    # SFS
    if usar_sfs:
        steps.append(("sfs", SequentialFeatureSelector(
            KNeighborsClassifier(**parametros), 
            n_features_to_select=num_atributos,
            direction="backward",
            scoring=f2_score,
            cv=5,
            n_jobs=1,
        )))

    # PCA
    if usar_pca:
        steps.append(("pca", PCA(n_components=num_dimensoes, random_state=SEMENTE_ALEATORIA)))

    steps.append(("modelo", KNeighborsClassifier(**parametros)))


    # Faz pipeline
    modelo = make_pipeline(*[s[1] for s in steps])

    return modelo

# %% [markdown]
# O código abaixo define a função que estima o desempenho do modelo de cada trial. Essa é a função que terá valor de retorno maximizado pelo optuna.

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

def funcao_objetivo(trial, X, y, num_folds):
    """Função objetivo do optuna, função cujo retorno será maximizado.

    Faz validação cruzada estratificada com métrica F2.

    Args:
        - trial: objeto tipo Trial do optuna;
        - x: ndarray. dataset de treino com atributos;
        - y: ndaray. dataset de treino com target;
        - num_folds: int. Número de folds da validação cruzada.
    
    Returns:
        - média dos resultados da validação cruzada.
    """
    modelo = cria_instancia_modelo(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring=f2_score,
        cv=num_folds,
    )

    return np.mean(metricas)

# %% [markdown]
# ## Otimização com optuna

# %% [markdown]
# O código abaixo cria ou carrega um 'estudo' a depender da existência dele. O 'estudo' contém informações sobre cada trial. A variável objeto_de_estudo acessa esse 'estudo'.

# %%
from optuna import create_study

NOME_DO_ESTUDO = "Knn_optuna"

objeto_de_estudo = create_study(
    direction="maximize",
    study_name=NOME_DO_ESTUDO,
    storage=f"sqlite:///{NOME_DO_ESTUDO}.db",
    load_if_exists=True,
)
# Out:
# [I 2025-11-03 21:24:36,084] A new study created in RDB with name: Knn_optuna

# %% [markdown]
# O código abaixo faz a otimização com optuna.

# %%
# Parâmetros
NUM_FOLDS = 10 # Número de folds da validação cruzada
NUM_TENTATIVAS = 200 # Quantidade de trials

def funcao_objetivo_parcial(trial):
    '''Função objetivo no formato exigido pelo optuna.'''
    return funcao_objetivo(trial, X_treino, y_treino, NUM_FOLDS)

# Faz a otimização
objeto_de_estudo.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2025-11-03 21:24:36,753] Trial 0 finished with value: 0.8183361795048907 and parameters: {'vizinhos': 35, 'pesos': 'distance', 'p_minkowski': 1.103430415113743, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 0 with value: 0.8183361795048907.
# [I 2025-11-03 21:25:38,826] Trial 1 finished with value: 0.8657536534693504 and parameters: {'vizinhos': 26, 'pesos': 'uniform', 'p_minkowski': 1.9181908292224263, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 1 with value: 0.8657536534693504.
# [I 2025-11-03 21:26:28,188] Trial 2 finished with value: 0.851004237615102 and parameters: {'vizinhos': 23, 'pesos': 'distance', 'p_minkowski': 1.2541413383607345, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 1 with value: 0.8657536534693504.
# [I 2025-11-03 21:27:18,706] Trial 3 finished with value: 0.8438585790426127 and parameters: {'vizinhos': 26, 'pesos': 'distance', 'p_minkowski': 1.747742850014884, 'normalizacao': 'none', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 1 with value: 0.8657536534693504.
# [I 2025-11-03 21:28:09,737] Trial 4 finished with value: 0.8283044955423604 and parameters: {'vizinhos': 44, 'pesos': 'distance', 'p_minkowski': 1.9687551225688142, 'normalizacao': 'standard', 'SFS': True, 'PCA': False, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 1 with value: 0.8657536534693504.
# [I 2025-11-03 21:28:10,423] Trial 5 finished with value: 0.8036778217145055 and parameters: {'vizinhos': 54, 'pesos': 'uniform', 'p_minkowski': 1.1021311737902775, 'normalizacao': 'standard', 'SFS': False, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 1 with value: 0.8657536534693504.
# [I 2025-11-03 21:28:52,174] Trial 6 finished with value: 0.8710628646085189 and parameters: {'vizinhos': 50, 'pesos': 'distance', 'p_minkowski': 1.9373605663836972, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 2}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:28:52,770] Trial 7 finished with value: 0.702619295551029 and parameters: {'vizinhos': 3, 'pesos': 'distance', 'p_minkowski': 1.387437864621746, 'normalizacao': 'standard', 'SFS': False, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:29:08,898] Trial 8 finished with value: 0.8014274536378749 and parameters: {'vizinhos': 48, 'pesos': 'distance', 'p_minkowski': 1.117289973343486, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:29:09,729] Trial 9 finished with value: 0.8603251454252107 and parameters: {'vizinhos': 51, 'pesos': 'distance', 'p_minkowski': 1.0224357909954065, 'normalizacao': 'minmax', 'SFS': False, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:29:40,216] Trial 10 finished with value: 0.8421371347001587 and parameters: {'vizinhos': 76, 'pesos': 'uniform', 'p_minkowski': 1.625610992751286, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:30:11,564] Trial 11 finished with value: 0.8583878581479876 and parameters: {'vizinhos': 68, 'pesos': 'uniform', 'p_minkowski': 1.9608087541657573, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 7, 'num_dimensoes': 2}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:30:45,615] Trial 12 finished with value: 0.8468025604537995 and parameters: {'vizinhos': 11, 'pesos': 'uniform', 'p_minkowski': 1.8188774426290135, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 2}. Best is trial 6 with value: 0.8710628646085189.
# [I 2025-11-03 21:31:26,808] Trial 13 finished with value: 0.8752460594885912 and parameters: {'vizinhos': 33, 'pesos': 'uniform', 'p_minkowski': 1.5768964646641814, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8752460594885912.
# [I 2025-11-03 21:32:11,324] Trial 14 finished with value: 0.8572670624343616 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.5604087952497288, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 13 with value: 0.8752460594885912.
# [I 2025-11-03 21:32:54,266] Trial 15 finished with value: 0.8737571674611623 and parameters: {'vizinhos': 38, 'pesos': 'uniform', 'p_minkowski': 1.4253795666849514, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 13 with value: 0.8752460594885912.
# [I 2025-11-03 21:33:11,488] Trial 16 finished with value: 0.8674837636192112 and parameters: {'vizinhos': 36, 'pesos': 'uniform', 'p_minkowski': 1.4092652256910418, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos':
 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:28:13,864] Trial 90 finished with value: 0.8496128198673365 and parameters: {'vizinhos': 61, 'pesos': 'distance', 'p_minkowski': 1.4156479087885636, 'normalizacao': 'minmax', 'SFS': True, 'PCA': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:29:08,322] Trial 91 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.5563526147978652, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:30:02,317] Trial 92 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 64, 'pesos': 'uniform', 'p_minkowski': 1.5412585439805082, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:30:57,328] Trial 93 finished with value: 0.8864300295805849 and parameters: {'vizinhos': 66, 'pesos': 'uniform', 'p_minkowski': 1.5032604969428867, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:31:11,851] Trial 94 finished with value: 0.8745052312089729 and parameters: {'vizinhos': 58, 'pesos': 'uniform', 'p_minkowski': 1.5709200541405761, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 8, 'num_dimensoes': 6}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:32:04,732] Trial 95 finished with value: 0.8834107877727304 and parameters: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.7854205702961727, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:33:10,761] Trial 96 finished with value: 0.8618653524045768 and parameters: {'vizinhos': 51, 'pesos': 'uniform', 'p_minkowski': 1.524438639426661, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:33:53,499] Trial 97 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.4636126191802157, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:34:48,145] Trial 98 finished with value: 0.8803272889646934 and parameters: {'vizinhos': 70, 'pesos': 'uniform', 'p_minkowski': 1.6043245647499815, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:34:48,739] Trial 99 finished with value: 0.8254620143559416 and parameters: {'vizinhos': 59, 'pesos': 'uniform', 'p_minkowski': 1.4901003507010435, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:35:28,573] Trial 100 finished with value: 0.8846703430992635 and parameters: {'vizinhos': 55, 'pesos': 'uniform', 'p_minkowski': 1.6398322992975272, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:36:22,068] Trial 101 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.4873813904337883, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:37:16,747] Trial 102 finished with value: 0.8864300295805849 and parameters: {'vizinhos': 65, 'pesos': 'uniform', 'p_minkowski': 1.5353092714953531, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:38:11,318] Trial 103 finished with value: 0.8857783769896143 and parameters: {'vizinhos': 67, 'pesos': 'uniform', 'p_minkowski': 1.5041018587548887, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:39:05,648] Trial 104 finished with value: 0.8834796792833648 and parameters: {'vizinhos': 62, 'pesos': 'uniform', 'p_minkowski': 1.4581920235497086, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:39:53,501] Trial 105 finished with value: 0.8810989145278351 and parameters: {'vizinhos': 57, 'pesos': 'uniform', 'p_minkowski': 1.5682278683963078, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:40:47,633] Trial 106 finished with value: 0.8810989145278351 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.2991516675718537, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:41:36,570] Trial 107 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 64, 'pesos': 'uniform', 'p_minkowski': 1.5130503728818325, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:42:31,068] Trial 108 finished with value: 0.8608633341359899 and parameters: {'vizinhos': 68, 'pesos': 'distance', 'p_minkowski': 1.1562691388809587, 'normalizacao': 'none', 'SFS': True, 'PCA': False, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:43:06,067] Trial 109 finished with value: 0.8838990873066421 and parameters: {'vizinhos': 72, 'pesos': 'uniform', 'p_minkowski': 1.9877894946549932, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:44:16,471] Trial 110 finished with value: 0.8573285389625056 and parameters: {'vizinhos': 62, 'pesos': 'uniform', 'p_minkowski': 1.432362602627097, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:45:10,065] Trial 111 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.559927474652439, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:46:04,505] Trial 112 finished with value: 0.8864300295805849 and parameters: {'vizinhos': 66, 'pesos': 'uniform', 'p_minkowski': 1.5445569793524347, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:46:57,569] Trial 113 finished with value: 0.8816898703346181 and parameters: {'vizinhos': 59, 'pesos': 'uniform', 'p_minkowski': 1.595728082740349, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:47:52,445] Trial 114 finished with value: 0.8857783769896143 and parameters: {'vizinhos': 69, 'pesos': 'uniform', 'p_minkowski': 1.475346534905548, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:48:45,708] Trial 115 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.6236034203039436, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:49:37,158] Trial 116 finished with value: 0.8760069921376378 and parameters: {'vizinhos': 56, 'pesos': 'uniform', 'p_minkowski': 1.5810016548211512, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:50:26,499] Trial 117 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.3551787899338545, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22:50:27,176] Trial 118 finished with value: 0.8109247390666839 and parameters: {'vizinhos': 65, 'pesos': 'uniform', 'p_minkowski': 1.6686018380521146, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 22
 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:43:26,431] Trial 182 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 64, 'pesos': 'uniform', 'p_minkowski': 1.2732580602979229, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:44:15,987] Trial 183 finished with value: 0.8846703430992635 and parameters: {'vizinhos': 59, 'pesos': 'uniform', 'p_minkowski': 1.3578833657992306, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:45:05,137] Trial 184 finished with value: 0.8834796792833648 and parameters: {'vizinhos': 62, 'pesos': 'uniform', 'p_minkowski': 1.4631121721652884, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:45:48,350] Trial 185 finished with value: 0.8857783769896143 and parameters: {'vizinhos': 67, 'pesos': 'uniform', 'p_minkowski': 1.4982520723735298, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:46:43,646] Trial 186 finished with value: 0.8864300295805849 and parameters: {'vizinhos': 65, 'pesos': 'uniform', 'p_minkowski': 1.2425948613772133, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:47:30,976] Trial 187 finished with value: 0.8810989145278351 and parameters: {'vizinhos': 57, 'pesos': 'uniform', 'p_minkowski': 1.521595088640802, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:48:25,107] Trial 188 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.6563221493452678, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:48:25,753] Trial 189 finished with value: 0.8131800496641443 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.4550183986452851, 'normalizacao': 'none', 'SFS': False, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:49:15,573] Trial 190 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 64, 'pesos': 'uniform', 'p_minkowski': 1.3588374781029575, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:50:04,838] Trial 191 finished with value: 0.8841313318743355 and parameters: {'vizinhos': 58, 'pesos': 'uniform', 'p_minkowski': 1.149790427069684, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:50:55,508] Trial 192 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.2244010250086312, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:51:45,941] Trial 193 finished with value: 0.8841313318743355 and parameters: {'vizinhos': 62, 'pesos': 'uniform', 'p_minkowski': 1.1752746840537374, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:52:28,996] Trial 194 finished with value: 0.8841313318743355 and parameters: {'vizinhos': 60, 'pesos': 'uniform', 'p_minkowski': 1.2864190984411723, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:53:19,069] Trial 195 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 63, 'pesos': 'uniform', 'p_minkowski': 1.2216758008600221, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:54:24,088] Trial 196 finished with value: 0.8732061886722506 and parameters: {'vizinhos': 66, 'pesos': 'uniform', 'p_minkowski': 1.1094230285684679, 'normalizacao': 'minmax', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:55:30,596] Trial 197 finished with value: 0.8353348536964965 and parameters: {'vizinhos': 68, 'pesos': 'uniform', 'p_minkowski': 1.4854705427301937, 'normalizacao': 'standard', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:56:17,490] Trial 198 finished with value: 0.8816898703346181 and parameters: {'vizinhos': 58, 'pesos': 'uniform', 'p_minkowski': 1.5714207189184348, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.
# [I 2025-11-03 23:57:12,419] Trial 199 finished with value: 0.8870948577102018 and parameters: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.2163682804930604, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 20 with value: 0.8870948577102018.

# %% [markdown]
# ## DataFrame dos trials

# %% [markdown]
# O código abaixo mostra o DataFrame contruído pelo objeto de estudo do optuna contendo todos os parâmetros de cada trial.

# %%
df_analysis = objeto_de_estudo.trials_dataframe()

df_analysis
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0  0.818336 2025-11-03 21:24:36.117971 2025-11-03 21:24:36.719692
# 1         1  0.865754 2025-11-03 21:24:36.769900 2025-11-03 21:25:38.768317
# 2         2  0.851004 2025-11-03 21:25:38.845130 2025-11-03 21:26:28.158967
# 3         3  0.843859 2025-11-03 21:26:28.209437 2025-11-03 21:27:18.616490
# 4         4  0.828304 2025-11-03 21:27:18.722764 2025-11-03 21:28:09.333619
# ..      ...       ...                        ...                        ...
# 195     195  0.887095 2025-11-03 23:52:29.015281 2025-11-03 23:53:19.035263
# 196     196  0.873206 2025-11-03 23:53:19.089622 2025-11-03 23:54:24.054230
# 197     197  0.835335 2025-11-03 23:54:24.111057 2025-11-03 23:55:30.562445
# 198     198  0.881690 2025-11-03 23:55:30.615386 2025-11-03 23:56:17.457247
# 199     199  0.887095 2025-11-03 23:56:17.510090 2025-11-03 23:57:12.386257
#
#                   duration  params_PCA  params_SFS params_normalizacao  \
# 0   0 days 00:00:00.601721        True       False                none
# 1   0 days 00:01:01.998417        True        True              minmax
# 2   0 days 00:00:49.313837       False        True            standard
# 3   0 days 00:00:50.407053       False        True                none
# 4   0 days 00:00:50.610855       False        True            standard
# ..                     ...         ...         ...                 ...
# 195 0 days 00:00:50.019982        True        True                none
# 196 0 days 00:01:04.964608        True        True              minmax
# 197 0 days 00:01:06.451388        True        True            standard
# 198 0 days 00:00:46.841861        True        True                none
# 199 0 days 00:00:54.876167        True        True                none
#
#      params_num_atributos  params_num_dimensoes  params_p_minkowski  \
# 0                       4                     3            1.103430
# 1                       2                     2            1.918191
# 2                       5                     3            1.254141
# 3                       3                     3            1.747743
# 4                       5                     5            1.968755
# ..                    ...                   ...                 ...
# 195                     4                     3            1.221676
# 196                     3                     3            1.109423
# 197                     3                     3            1.485471
# 198                     4                     3            1.571421
# 199                     3                     3            1.216368
#
#     params_pesos  params_vizinhos     state
# 0       distance               35  COMPLETE
# 1        uniform               26  COMPLETE
# 2       distance               23  COMPLETE
# 3       distance               26  COMPLETE
# 4       distance               44  COMPLETE
# ..           ...              ...       ...
# 195      uniform               63  COMPLETE
# 196      uniform               66  COMPLETE
# 197      uniform               68  COMPLETE
# 198      uniform               58  COMPLETE
# 199      uniform               61  COMPLETE
#
# [200 rows x 14 columns]

# %% [markdown]
# ## Melhor modelo

# %% [markdown]
# O código abaixo mostra o melhor modelo encontrado pelo optuna e seus parâmetros. Note que os parâmetros 'num_atributos' e 'num_dimensoes' só influenciam caso 'SFS' e 'PCA' sejam True respectivamente, pois são seus respectivos hiperparâmetros.

# %%
melhor_trial = objeto_de_estudo.best_trial

print(f"Número do melhor trial: {melhor_trial.number}")
print(f"Parâmetros do melhor trial: {melhor_trial.params}")
# Out:
# Número do melhor trial: 20
# Parâmetros do melhor trial: {'vizinhos': 61, 'pesos': 'uniform', 'p_minkowski': 1.2614559083830308, 'normalizacao': 'none', 'SFS': True, 'PCA': True, 'num_atributos': 5, 'num_dimensoes': 4}

# %% [markdown]
# Este notebook se encerra aqui. O modelo será usado no notebook chamado 'Resultados_Discussão'.

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] Documentação do optuna. Acesso em: 31/10/2025. Disponível em: https://optuna.readthedocs.io/en/stable/
#
# [2] Página da Regressão Logística da documentação do scikit-learn. Acesso em: 31/10/2025. Disponível em: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression
#
# [3] Sperat, Walter. *Using optuna with sklearn the right way*. Acesso em 31/10/2025. Disponível em: https://medium.com/@walter_sperat/using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
