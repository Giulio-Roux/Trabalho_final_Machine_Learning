# %% [markdown]
# # Regressão Logística

# %% [markdown]
# ## Introdução

# %% [markdown]
# Este notebook visa fazer a otimização de **hiperparâmetros**, de estratégia de **normalização**, de **seleção de atributos** e de **redução de dimensionalidade**. A seleção de atributos é realizada por *Recursive Feature Elimination* (**RFE**, ou Eliminação Recursiva de Atributos em português), a otimização testa a ausência ou não dessa estratégia. A redução de dimensionalidade é realizada por *Principal Component Analysis* (**PCA**, ou Análise de Componenetes Principais em português), é testada sua ausência também. Para normalização, são testadas a ausência, ou a normalização **padrão** ou a pelos **mínimos e máximos**. A otimização é feita usando o módulo **optuna**.

# %% [markdown]
# ### Modelo

# %% [markdown]
# O modelo otimizado é uma Regressão Logística do scikit-learn [2]. O argumento 'penalty' é usado na configuração 'elasticnet'. Dessa forma, o único hiperparâmetro otimizado é:
#
# - `l1_ratio`: float entre 0 e 1 que representa a razão entre as regularizações, sendo que 1 (l1) é Lasso e 0 é Ridge (l2);

# %% [markdown]
# ## Carrega os dados

# %%
from pandas impor read_csv

# Dados de treino
X_treino = read_csv('../Dados/dados_tratados/X_treino.csv')
y_treino = read_csv('../Dados/dados_tratados/y_treino.csv').values.ravel()

# %% [markdown]
# ## Define algumas variáveis úteis

# %%
# Parâmetros
SEMENTE_ALEATORIA = 9 # Random state
num_max_atributos = len(X_treino.columns) - 1 # Para RFE

X_treino = X_treino.values

# %% [markdown]
# ## Definição de funções para o optuna

# %% [markdown]
# O código abaixo define a função que cria uma instância do modelo. É nela que o pipeline é montado de acordo com as sugestões definidas pelo optuna.

# %%
from sklearn.linear_model import LogisticRegression # algoritmo de aprendizado de máquina
from sklearn.preprocessing import StandardScaler, MinMaxScaler # normalização
from sklearn.feature_selection import RFE # seleção de atributos
from sklearn.decomposition import PCA # redução de dimensionalidade
from sklearn.pipeline import make_pipeline

def cria_instancia_modelo(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.

    """
    parametros = {
        "penalty": "elasticnet",
        "l1_ratio": trial.suggest_float("razão_regularização", 0, 1), # 0 -> l2, 1 -> l1
        "solver": "saga", # única capaz de resolver elasticnet
        "max_iter": 5000,
        "class_weight": "balanced", # Dados desbalanceados
        "n_jobs": -1,
        "random_state": SEMENTE_ALEATORIA,
    }

    normalizacao = trial.suggest_categorical("normalizacao", ["standard", "minmax"])
    usar_pca = trial.suggest_categorical("PCA", [True, False])
    usar_rfe = trial.suggest_categorical("RFE", [True, False])

    num_atributos = trial.suggest_int("num_atributos", 2, num_max_atributos) # para RFE
    num_dimensoes = trial.suggest_int("num_dimensoes", 2, num_atributos) # para PCA
        
    
    steps = []

    if normalizacao == "standard":
        steps.append(("normalizador", StandardScaler()))
    else:
        steps.append(("normalizador", MinMaxScaler()))

    if usar_rfe:
        steps.append(("rfe", RFE(LogisticRegression(**parametros), n_features_to_select=num_atributos)))

    if usar_pca:
        steps.append(("pca", PCA(n_components=num_dimensoes, random_state=SEMENTE_ALEATORIA)))

    steps.append(("modelo", LogisticRegression(**parametros)))

    modelo = make_pipeline(*[s[1] for s in steps])

    return modelo

# %% [markdown]
# O código abaixo define a função que estima o desempenho do modelo de cada trial. Essa é a função que terá valor de retorno maximizado pelo optuna.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer
import numpy as np

f2_score = make_scorer(fbeta_score, beta=2)

def funcao_objetivo(trial, X, y, num_folds):
    """Função objetivo do optuna.

    Faz validação cruzada estratificada com métrica F2.

    """
    modelo = cria_instancia_modelo(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring=f2_score,
        cv=num_folds,
    )

    return np.mean(metricas)

# %% [markdown]
# ## Otimização com optuna

# %% [markdown]
# O código abaixo cria ou carrega um 'estudo' a depender da existência dele. O 'estudo' contém informações sobre cada trial. A variável objeto_de_estudo acessa esse 'estudo'.

# %%
from optuna import create_study

NOME_DO_ESTUDO = "Regressao_Logistica_optuna"

objeto_de_estudo = create_study(
    direction="maximize",
    study_name=NOME_DO_ESTUDO,
    storage=f"sqlite:///{NOME_DO_ESTUDO}.db",
    load_if_exists=True,
)
# Out:
# [I 2025-11-03 21:19:41,637] A new study created in RDB with name: Regressao_Logistica_optuna

# %% [markdown]
# O código abaixo faz a otimização com optuna.

# %%
# Parâmetros
NUM_FOLDS = 10 # Validação cruzada
NUM_TENTATIVAS = 200 # Quantidade de trials

def funcao_objetivo_parcial(trial):
    return funcao_objetivo(trial, X_treino, y_treino, NUM_FOLDS)

# Faz a otimização
objeto_de_estudo.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2025-11-03 21:19:42,578] Trial 0 finished with value: 0.7373487359359844 and parameters: {'razão_regularização': 0.988640698756119, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 2}. Best is trial 0 with value: 0.7373487359359844.
# [I 2025-11-03 21:19:43,125] Trial 1 finished with value: 0.7709377883508247 and parameters: {'razão_regularização': 0.20792770323721643, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 1 with value: 0.7709377883508247.
# [I 2025-11-03 21:19:43,573] Trial 2 finished with value: 0.8595923668227776 and parameters: {'razão_regularização': 0.5268301113325903, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:45,515] Trial 3 finished with value: 0.857861205358855 and parameters: {'razão_regularização': 0.6003096685955838, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:47,893] Trial 4 finished with value: 0.8181660217799884 and parameters: {'razão_regularização': 0.02396076934372271, 'normalizacao': 'standard', 'PCA': True, 'RFE': True, 'num_atributos': 7, 'num_dimensoes': 3}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:48,555] Trial 5 finished with value: 0.8422882058533274 and parameters: {'razão_regularização': 0.984870621468509, 'normalizacao': 'standard', 'PCA': False, 'RFE': False, 'num_atributos': 7, 'num_dimensoes': 2}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:49,048] Trial 6 finished with value: 0.7373487359359844 and parameters: {'razão_regularização': 0.7559125900025813, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:49,540] Trial 7 finished with value: 0.8527912213399859 and parameters: {'razão_regularização': 0.7498756525057112, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:50,033] Trial 8 finished with value: 0.7373487359359844 and parameters: {'razão_regularização': 0.8759362234473353, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:51,412] Trial 9 finished with value: 0.8548518317155318 and parameters: {'razão_regularização': 0.2977447939083956, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:53,122] Trial 10 finished with value: 0.8524635424584235 and parameters: {'razão_regularização': 0.4440882241968044, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:55,115] Trial 11 finished with value: 0.857861205358855 and parameters: {'razão_regularização': 0.580944217099257, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19:56,840] Trial 12 finished with value: 0.8549144467932772 and parameters: {'razão_regularização': 0.5131172913196053, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 2 with value: 0.8595923668227776.
# [I 2025-11-03 21:19
finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.13443969135859568, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:03,893] Trial 160 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.328869672187951, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:04,863] Trial 161 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.10428572797461405, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:05,583] Trial 162 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.08532776421203306, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:06,262] Trial 163 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.12319461501025242, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:06,863] Trial 164 finished with value: 0.8595923668227776 and parameters: {'razão_regularização': 0.7047401957201052, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:07,560] Trial 165 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.15068372599526464, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:08,075] Trial 166 finished with value: 0.8595923668227776 and parameters: {'razão_regularização': 0.5172192985003212, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:08,715] Trial 167 finished with value: 0.8534649158423855 and parameters: {'razão_regularização': 0.7842713677398873, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:10,258] Trial 168 finished with value: 0.7879750454727976 and parameters: {'razão_regularização': 0.21618736322228393, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:11,886] Trial 169 finished with value: 0.8524635424584235 and parameters: {'razão_regularização': 0.25537581185239405, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:12,517] Trial 170 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.44861350599446836, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:13,130] Trial 171 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.2004660578588696, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:13,802] Trial 172 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.23940212408140193, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:14,423] Trial 173 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.17962838467232556, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:15,036] Trial 174 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.11515879120598113, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:15,720] Trial 175 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.26974970742632276, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:16,433] Trial 176 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.1667527201594443, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:17,036] Trial 177 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.41362108052771035, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:17,571] Trial 178 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.04688748756137333, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:18,258] Trial 179 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.22256590929061862, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:19,098] Trial 180 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.08414401731004242, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:19,872] Trial 181 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.07479784921557517, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:20,518] Trial 182 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.09703457510353514, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:21,245] Trial 183 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.05736431553764072, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:21,943] Trial 184 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.14077117604351969, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:22,535] Trial 185 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.29849566392895016, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:23,414] Trial 186 finished with value: 0.8571503450175664 and parameters: {'razão_regularização': 0.1915640429058591, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 8, 'num_dimensoes': 7}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:24,220] Trial 187 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.02252003909919574, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:24,866] Trial 188 finished with value: 0.8595923668227776 and parameters: {'razão_regularização': 0.48125452762029663, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:25,575] Trial 189 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.24316615620564885, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:26,188] Trial 190 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.11426012676682173, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:26,813] Trial 191 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.27522705465355285, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:27,430] Trial 192 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.3051740648661564, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:28,082] Trial 193 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.22666926101619236, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:28,737] Trial 194 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.28364811203040685, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:29,539] Trial 195 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.25498799173973047, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:30,372] Trial 196 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.20400150139279752, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:31,411] Trial 197 finished with value: 0.7879750454727976 and parameters: {'razão_regularização': 0.1531995701268578, 'normalizacao': 'standard', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:33,298] Trial 198 finished with value: 0.857861205358855 and parameters: {'razão_regularização': 0.2307411085283669, 'normalizacao': 'minmax', 'PCA': False, 'RFE': True, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.
# [I 2025-11-03 21:22:33,823] Trial 199 finished with value: 0.8624891803279221 and parameters: {'razão_regularização': 0.43663010350006926, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 26 with value: 0.8624891803279221.

# %% [markdown]
# ## DataFrame dos trials

# %% [markdown]
# O código abaixo mostra o DataFrame contruído pelo objeto de estudo do optuna contendo todos os parâmetros de cada trial.

# %%
df_analysis = objeto_de_estudo.trials_dataframe()

df_analysis
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0  0.737349 2025-11-03 21:19:41.670370 2025-11-03 21:19:42.542271
# 1         1  0.770938 2025-11-03 21:19:42.598742 2025-11-03 21:19:43.097914
# 2         2  0.859592 2025-11-03 21:19:43.142339 2025-11-03 21:19:43.544635
# 3         3  0.857861 2025-11-03 21:19:43.593152 2025-11-03 21:19:45.478827
# 4         4  0.818166 2025-11-03 21:19:45.535848 2025-11-03 21:19:47.862296
# ..      ...       ...                        ...                        ...
# 195     195  0.862489 2025-11-03 21:22:28.756110 2025-11-03 21:22:29.450911
# 196     196  0.862489 2025-11-03 21:22:29.556411 2025-11-03 21:22:30.301031
# 197     197  0.787975 2025-11-03 21:22:30.392366 2025-11-03 21:22:30.984533
# 198     198  0.857861 2025-11-03 21:22:31.428628 2025-11-03 21:22:33.267173
# 199     199  0.862489 2025-11-03 21:22:33.315143 2025-11-03 21:22:33.793189
#
#                   duration  params_PCA  params_RFE params_normalizacao  \
# 0   0 days 00:00:00.871901        True       False            standard
# 1   0 days 00:00:00.499172        True       False            standard
# 2   0 days 00:00:00.402296        True       False              minmax
# 3   0 days 00:00:01.885675       False        True              minmax
# 4   0 days 00:00:02.326448        True        True            standard
# ..                     ...         ...         ...                 ...
# 195 0 days 00:00:00.694801        True       False              minmax
# 196 0 days 00:00:00.744620        True       False              minmax
# 197 0 days 00:00:00.592167        True       False            standard
# 198 0 days 00:00:01.838545       False        True              minmax
# 199 0 days 00:00:00.478046        True       False              minmax
#
#      params_num_atributos  params_num_dimensoes  params_razão_regularização  \
# 0                       4                     2                    0.988641
# 1                       5                     3                    0.207928
# 2                       5                     4                    0.526830
# 3                       4                     4                    0.600310
# 4                       7                     3                    0.023961
# ..                    ...                   ...                         ...
# 195                     5                     4                    0.254988
# 196                     5                     4                    0.204002
# 197                     5                     4                    0.153200
# 198                     5                     4                    0.230741
# 199                     5                     4                    0.436630
#
#         state
# 0    COMPLETE
# 1    COMPLETE
# 2    COMPLETE
# 3    COMPLETE
# 4    COMPLETE
# ..        ...
# 195  COMPLETE
# 196  COMPLETE
# 197  COMPLETE
# 198  COMPLETE
# 199  COMPLETE
#
# [200 rows x 12 columns]

# %% [markdown]
# ## Melhor modelo

# %% [markdown]
# O código abaixo mostra o melhor modelo encontrado pelo optuna e seus parâmetros. Note que os parâmetros 'num_atributos' e 'num_dimensoes' só influenciam caso 'RFE' e 'PCA' sejam True respectivamente, pois são seus respectivos hiperparâmetros.

# %%
melhor_trial = objeto_de_estudo.best_trial

print(f"Número do melhor trial: {melhor_trial.number}")
print(f"Parâmetros do melhor trial: {melhor_trial.params}")
# Out:
# Número do melhor trial: 26
# Parâmetros do melhor trial: {'razão_regularização': 0.43784276614287854, 'normalizacao': 'minmax', 'PCA': True, 'RFE': False, 'num_atributos': 4, 'num_dimensoes': 4}

# %% [markdown]
# Este notebook se encerra aqui. O modelo será usado no notebook chamado 'Resultados_Discussão'.

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] Documentação do optuna. Acesso em: 31/10/2025. Disponível em: https://optuna.readthedocs.io/en/stable/
#
# [2] Página da Regressão Logística da documentação do scikit-learn. Acesso em: 31/10/2025. Disponível em: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression
#
# [3] Sperat, Walter. *Using optuna with sklearn the right way*. Acesso em 31/10/2025. Disponível em: https://medium.com/@walter_sperat/using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
