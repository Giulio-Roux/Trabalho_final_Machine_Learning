# %% [markdown]
# # SVC - C-Support Vector Classification

# %% [markdown]
# ## Introdução

# %% [markdown]
# Este notebook visa fazer a otimização de **hiperparâmetros**, de estratégia de **normalização**, de **seleção de atributos** e de **redução de dimensionalidade**. A seleção de atributos é realizada por *Sequential Feature Selection* (**SFS**, ou Seleção Sequencial de Atributos em português) por remoção de atributo, a otimização testa a ausência ou não dessa estratégia. A redução de dimensionalidade é realizada por *Principal Component Analysis* (**PCA**, ou Análise de Componenetes Principais em português), é testada sua ausência também. Para normalização, são testadas a ausência, ou a normalização **padrão** ou a pelos **mínimos e máximos**. A otimização é feita usando o módulo **optuna**.

# %% [markdown]
# ### Modelo

# %% [markdown]
# O algoritmo deste notebook é o Support Vector Machine (SVM) para Classificação (ou seja, SVC). O seu método de segregação de dados pelo corte por hiperplanos possui muitas possibilidades geométricas e de proporção, assim, quando há muitos atributos e não se sabe se apresentam algum padrão de distribuição multidimensional possível, saber o kernel utilizado que melhor se adeque pode ser um problema de tentativa e erro.

# %% [markdown]
# Os hiperparâmetros a serem otimizados são:
# * `C`: coeficiente da relação entre a margem da transição do hiperplano e a quantidade de objetos não bem separados - um "C" menor aumenta a margem e pode abranger objetos em si, de forma que, ao custo de poder errar mais, generaliza-se melhor;
# * `gamma`: define a influência individual de um objeto sobre o encaixe ("fitting") do hiperplano (para sigmoid, poly e RBF);
# * `kernel`: método de traçagem do plano, utilizaremos os 4 citados;
# * `coef0`: termo independente do kernel polinomial e do sigmoidal;
# * `degree`: grau do kernel polinomial.

# %%
from pandas import read_csv

# Dados de treino
X_treino = read_csv('../Dados/dados_tratados/X_treino.csv')
y_treino = read_csv('../Dados/dados_tratados/y_treino.csv').values.ravel()

# %%
# Parâmetros
SEMENTE_ALEATORIA = 9 # Random state
num_max_atributos = len(X_treino.columns) - 1

X_treino = X_treino.values

# %%
from sklearn.svm import SVC # algoritmo de aprendizado de máquina
from sklearn.preprocessing import StandardScaler, MinMaxScaler # normalização
from sklearn.feature_selection import SequentialFeatureSelector # seleção de atributos
from sklearn.decomposition import PCA # redução de dimensionalidade
from sklearn.pipeline import make_pipeline

def cria_instancia_modelo(trial):
    """Cria uma instância do modelo.

    Args:
      trial: objeto tipo Trial do optuna.

    Returns:
      Uma instância do modelo desejado.

    """
    parametros = {
        "C": trial.suggest_float("C_coef", 0.001, 10),
        "kernel": trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"]),
        "gamma": trial.suggest_categorical("fit_hiperplano", ["scale", "auto"]),
        "coef0": trial.suggest_float("coef0", 0, 10),
        "degree": trial.suggest_int("grau_polinomial", 1, 5),
        "max_iter": -1,
        "class_weight": "balanced", # Dados desbalanceados
    }

    normalizacao = trial.suggest_categorical("normalizacao", ["standard", "minmax"])
    usar_pca = trial.suggest_categorical("PCA", [True, False])
    usar_sfs = trial.suggest_categorical("SFS", [True, False])

    num_atributos = trial.suggest_int("num_atributos", 2, num_max_atributos) # para RFE
    num_dimensoes = trial.suggest_int("num_dimensoes", 2, num_atributos) # para PCA
        
    
    steps = []

    if normalizacao == "standard":
        steps.append(("normalizador", StandardScaler()))
    else:
        steps.append(("normalizador", MinMaxScaler()))

    if usar_sfs:
        steps.append(("sfs", SequentialFeatureSelector(
            SVC(**parametros), 
            n_features_to_select=num_atributos,
            direction="backward",
            scoring=f2_score,
            cv=5,
            n_jobs=1,
        )))

    if usar_pca:
        steps.append(("pca", PCA(n_components=num_dimensoes, random_state=SEMENTE_ALEATORIA)))

    steps.append(("modelo", SVC(**parametros)))

    modelo = make_pipeline(*[s[1] for s in steps])

    return modelo

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer
import numpy as np

f2_score = make_scorer(fbeta_score, beta=2)

def funcao_objetivo(trial, X, y, num_folds):
    """Função objetivo do optuna.

    Faz validação cruzada estratificada com métrica F2.

    """
    modelo = cria_instancia_modelo(trial)

    metricas = cross_val_score(
        modelo,
        X,
        y,
        scoring=f2_score,
        cv=num_folds,
    )

    return np.mean(metricas)

# %%
from optuna import create_study

NOME_DO_ESTUDO = "SVC_optuna"

objeto_de_estudo = create_study(
    direction="maximize",
    study_name=NOME_DO_ESTUDO,
    storage=f"sqlite:///{NOME_DO_ESTUDO}.db",
    load_if_exists=True,
)
# Out:
# [I 2025-11-03 16:14:53,577] A new study created in RDB with name: SVC_optuna

# %%
# Parâmetros
NUM_FOLDS = 10 # Validação cruzada
NUM_TENTATIVAS = 200 # Quantidade de trials

def funcao_objetivo_parcial(trial):
    return funcao_objetivo(trial, X_treino, y_treino, NUM_FOLDS)

# Faz a otimização
objeto_de_estudo.optimize(funcao_objetivo_parcial, n_trials=NUM_TENTATIVAS)
# Out:
# [I 2025-11-03 16:14:54,309] Trial 0 finished with value: 0.857341731889021 and parameters: {'C_coef': 6.3032655076203605, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 1.382933466562103, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 2}. Best is trial 0 with value: 0.857341731889021.
# [I 2025-11-03 16:15:43,058] Trial 1 finished with value: 0.5296277697570775 and parameters: {'C_coef': 4.530419040746595, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 8.694688607719169, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': True, 'SFS': True, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 0 with value: 0.857341731889021.
# [I 2025-11-03 16:15:44,175] Trial 2 finished with value: 0.8022837692862039 and parameters: {'C_coef': 1.6536834024947897, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.603584464877635, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 2}. Best is trial 0 with value: 0.857341731889021.
# [I 2025-11-03 16:16:15,607] Trial 3 finished with value: 0.8607328954580622 and parameters: {'C_coef': 8.538913538004937, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 1.665078748290606, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 3 with value: 0.8607328954580622.
# [I 2025-11-03 16:16:32,075] Trial 4 finished with value: 0.8333731428180583 and parameters: {'C_coef': 6.915971638881938, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 8.6633536863603, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 3 with value: 0.8607328954580622.
# [I 2025-11-03 16:16:33,931] Trial 5 finished with value: 0.8357546986862939 and parameters: {'C_coef': 8.108065084982888, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 4.679441112274421, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': False, 'num_atributos': 5, 'num_dimensoes': 4}. Best is trial 3 with value: 0.8607328954580622.
# [I 2025-11-03 16:16:36,033] Trial 6 finished with value: 0.857341731889021 and parameters: {'C_coef': 5.852404816363835, 'kernel': 'linear', 'fit_hiperplano': 'auto', 'coef0': 6.593983861226693, 'grau_polinomial': 1, 'normalizacao': 'standard', 'PCA': False, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 3 with value: 0.8607328954580622.
# [I 2025-11-03 16:16:52,646] Trial 7 finished with value: 0.8623455358305471 and parameters: {'C_coef': 7.954791469663015, 'kernel': 'rbf', 'fit_hiperplano': 'scale', 'coef0': 8.939625101450268, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:17:04,434] Trial 8 finished with value: 0.8590059398618852 and parameters: {'C_coef': 6.849295636312211, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 3.7855934926698733, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:17:34,880] Trial 9 finished with value: 0.8544449183838765 and parameters: {'C_coef': 0.5821874356408406, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 2.131296508818389, 'grau_polinomial': 5, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 3, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:17:42,004] Trial 10 finished with value: 0.8457217896535895 and parameters: {'C_coef': 9.812480672690448, 'kernel': 'rbf', 'fit_hiperplano': 'scale', 'coef0': 6.490808463313078, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 8, 'num_dimensoes': 8}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:18:10,381] Trial 11 finished with value: 0.850605295363219 and parameters: {'C_coef': 9.86539295293557, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 0.7727105198046661, 'grau_polinomial': 5, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:18:34,694] Trial 12 finished with value: 0.857341731889021 and parameters: {'C_coef': 3.759070050468625, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 3.1185695895606336, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:19:26,974] Trial 13 finished with value: 0.5296277697570775 and parameters: {'C_coef': 8.259588002128169, 'kernel': 'sigmoid', 'fit_hiperplano': 'auto', 'coef0': 6.3809726340518225, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:21:05,380] Trial 14 finished with value: 0.8470674128078963 and parameters: {'C_coef': 8.272435384124842, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 0.004653179579896305, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:21:26,042] Trial 15 finished with value: 0.8542432570655795 and parameters: {'C_coef': 8.706477841207027, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 5.4991365364059295, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:21:32,938] Trial 16 finished with value: 0.8590059398618852 and parameters: {'C_coef': 2.7066074235480166, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 7.69842756483473, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 8, 'num_dimensoes': 6}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:26:19,247] Trial 17 finished with value: 0.8550122886996689 and parameters: {'C_coef': 5.101047462244616, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 9.986225134787206, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:26:50,072] Trial 18 finished with value: 0.5128042959158335 and parameters: {'C_coef': 7.1283401021881225, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 2.64574259771078, 'grau_polinomial': 5, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 2}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:27:16,530] Trial 19 finished with value: 0.8488759367119536 and parameters: {'C_coef': 9.160547350333452, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 4.078272903215917, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:31:13,109] Trial 20 finished with value: 0.8571418576692048 and parameters: {'C_coef': 7.857634245827351, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 9.711101773465227, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 4}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:31:23,944] Trial 21 finished with value: 0.8590059398618852 and parameters: {'C_coef': 7.218659808819933, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 3.6618260276028605, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:31:34,788] Trial 22 finished with value: 0.8590059398618852 and parameters: {'C_coef': 5.686253689536766, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 1.9686768028480648, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:31:52,534] Trial 23 finished with value: 0.857341731889021 and parameters: {'C_coef': 6.686043145483637, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 5.355090547777909, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:31:58,476] Trial 24 finished with value: 0.8590059398618852 and parameters: {'C_coef': 7.638011446598133, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 4.0776724700623035, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 8, 'num_dimensoes': 8}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:32:18,718] Trial 25 finished with value: 0.857341731889021 and parameters: {'C_coef': 9.246953716511214, 'kernel': 'poly', 'fit_hiperplano': 'auto', 'coef0': 3.1739367540789014, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 5, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:32:19,358] Trial 26 finished with value: 0.8240327973023073 and parameters: {'C_coef': 8.952661448752687, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 1.0003020207932205, 'grau_polinomial': 1, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:32:50,263] Trial 27 finished with value: 0.3033707865168539 and parameters: {'C_coef': 4.466983966248181, 'kernel': 'sigmoid', 'fit_hiperplano': 'auto', 'coef0': 7.4548536590716346, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:33:18,826] Trial 28 finished with value: 0.85378716051575 and parameters: {'C_coef': 6.11992622389384, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 0.15172461129963444, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:33:19,504] Trial 29 finished with value: 0.857341731889021 and parameters: {'C_coef': 6.44716119617097, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 2.177825308248347, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 8}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:33:36,341] Trial 30 finished with value: 0.857341731889021 and parameters: {'C_coef': 7.526256874369607, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 4.812110027548044, 'grau_polinomial': 1, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 4}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:33:43,456] Trial 31 finished with value: 0.8590059398618852 and parameters: {'C_coef': 2.956561532560012, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 7.771372595588439, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 8, 'num_dimensoes': 7}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:33:55,943] Trial 32 finished with value: 0.8590059398618852 and parameters: {'C_coef': 2.3988608263458113, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 9.323989940362093, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 7 with value: 0.8623455358305471.
# [I 2025-11-03 16:34:09,909] Trial 33 finished with value: 0.8630047914462498 and parameters: {'C_coef': 0.555998571851247, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 7.917930846090671, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 33 with value: 0.8630047914462498.
# [I 2025-11-03 16:34:25,191] Trial 34 finished with value: 0.8657689851497432 and parameters: {'C_coef': 0.2371382093746135, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 9.176535267262217, 'grau_polinomial': 3, 'normalizacao': 'minmax', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 34 with value: 0.8657689851497432.
# [I 2025-11-03 16:34:25,766] Trial 35 finished with value: 0.8601250022211685 and parameters: {'C_coef': 0.33265300700258815, 'kernel': 'rbf', 'fit_hiperplano': 'scale', 'coef0': 8.364539247351457, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 34 with value: 0.8657689851497432.
# [I 2025-11-03 16:34:38,743] Trial 36 finished with value: 0.8590059398618852 and parameters: {'C_coef': 1.3084322792917225, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 8.928829734622786, 'grau_polinomial': 4, 'normalizacao': 'minmax', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 34 with value: 0.8657689851497432.
# [I 2025-11-03 16:34:40,370] Trial 37 finished with value: 0.7468094130156796 and parameters: {'C_coef': 0.016432995269324735, 'kernel': 'rbf', 'fit_hiperplano': 'auto', 'coef0': 8.217241484555327, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 2}. Best is trial 34 with value: 0.8657689851497432.
# [I 2025-11-03 16:35:00,372] Trial 38 finished with value: 0.8683813068030887 and parameters: {'C_coef': 1.1961540447408723, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.062583559943493, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:20,522] Trial 39 finished with value: 0.8683813068030887 and parameters: {'C_coef': 1.151385657109052, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.167977716330888, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:21,491] Trial 40 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.1599612348131498, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.245996705894356, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:22,209] Trial 41 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.1490968908995522, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.017802726496045, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:22,921] Trial 42 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.4667713275590861, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.072044398084803, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:23,560] Trial 43 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.3954633285233968, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.255453548216915, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:24,268] Trial 44 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.965771290253465, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.96775550117931, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:24,942] Trial 45 finished with value: 0.866026048152866 and parameters: {'C_coef': 0.9900587107657159, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.085791244830662, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:25,633] Trial 46 finished with value: 0.866026048152866 and parameters: {'C_coef': 2.2462130401625755, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.060386807286095, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:26,308] Trial 47 finished with value: 0.866026048152866 and parameters: {'C_coef': 0.9868875632194142, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 5.714572576316444, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:27,136] Trial 48 finished with value: 0.866026048152866 and parameters: {'C_coef': 3.5161183986567055, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.484697156126991, 'grau_polinomial': 4, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:27,868] Trial 49 finished with value: 0.8032178341320316 and parameters: {'C_coef': 1.672449689601796, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.777241178776739, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:28,714] Trial 50 finished with value: 0.866026048152866 and parameters: {'C_coef': 0.8626589356812753, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.579134650961471, 'grau_polinomial': 4, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:30,375] Trial 51 finished with value: 0.8032178341320316 and parameters: {'C_coef': 1.6118587936710997, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.245350749848267, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:31,321] Trial 52 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.417132015859612, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 5.900930973581678, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:32,210] Trial 53 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.92329705575975, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.42028433116277, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:32,951] Trial 54 finished with value: 0.866026048152866 and parameters: {'C_coef': 3.1353269776906902, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.768609991070631, 'grau_polinomial': 4, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:33,796] Trial 55 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.1729263397984373, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.146986983641062, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:34,444] Trial 56 finished with value: 0.8032178341320316 and parameters: {'C_coef': 0.6888756630486055, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.532927267278568, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:35,206] Trial 57 finished with value: 0.866026048152866 and parameters: {'C_coef': 2.3812799462011656, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 5.178185498958797, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:35,951] Trial 58 finished with value: 0.8032178341320316 and parameters: {'C_coef': 1.9432096897634594, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.207074664536103, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:36,854] Trial 59 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.4421100148490775, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.802797266551004, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:37,801] Trial 60 finished with value: 0.5296277697570775 and parameters: {'C_coef': 2.7740824169678486, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 7.353312950121105, 'grau_polinomial': 4, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:38,729] Trial 61 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.9329724105000092, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.924931380104833, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:39,679] Trial 62 finished with value: 0.8630792895872881 and parameters: {'C_coef': 0.4960464328837516, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.972554499344689, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:41,134] Trial 63 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.0535039565558666, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.106230711630491, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:42,098] Trial 64 finished with value: 0.866026048152866 and parameters: {'C_coef': 2.160880769998732, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.177831803198262, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:42,801] Trial 65 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.5642615786912464, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.651409699981713, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:43,595] Trial 66 finished with value: 0.8032178341320316 and parameters: {'C_coef': 0.6697422042947134, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.24023902688523, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:44,351] Trial 67 finished with value: 0.866026048152866 and parameters: {'C_coef': 2.6615601474603294, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.576453372173301, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:45,117] Trial 68 finished with value: 0.866026048152866 and parameters: {'C_coef': 3.331232864760544, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.664546650820309, 'grau_polinomial': 4, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:46,064] Trial 69 finished with value: 0.5296277697570775 and parameters: {'C_coef': 1.7956234504244089, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 5.602392671786434, 'grau_polinomial': 5, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:46,830] Trial 70 finished with value: 0.866026048152866 and parameters: {'C_coef': 4.167814159856604, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.9266556929367225, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:47,516] Trial 71 finished with value: 0.8032178341320316 and parameters: {'C_coef': 0.9565902730805562, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.702571421622999, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 4}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:48,315] Trial 72 finished with value: 0.8630792895872881 and parameters: {'C_coef': 0.11657479179126806, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.02958506613939, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:48,859] Trial 73 finished with value: 0.866026048152866 and parameters: {'C_coef': 1.2177384493773482, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.071119478674612, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 8, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:35:50,574] Trial 74 finished with value: 0.8630792895872881 and parameters: {'C_coef': 0.4537047052936002, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 6.231498421737769, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': False, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:36:07,657] Trial 75 finished with value: 0.8683813068030887 and parameters: {'C_coef': 0.8068791444070933, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.070527300143635, 'grau_polinomial': 3, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:36:28,487] Trial 76 finished with value: 0.8677557203157569 and parameters: {'C_coef': 1.3285232441722663, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.449545731133594, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:36:49,372] Trial 77 finished with value: 0.8683813068030887 and parameters: {'C_coef': 1.3102813595677627, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.797071181159105, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:37:05,659] Trial 78 finished with value: 0.8683813068030887 and parameters: {'C_coef': 0.7155038451620553, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.993378681366027, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:37:28,094] Trial 79 finished with value: 0.7537657007915601 and parameters: {'C_coef': 0.7930962968296131, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 9.476992402859102, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:38:25,852] Trial 80 finished with value: 0.8660768915057535 and parameters: {'C_coef': 5.191424860951258, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.991511140410296, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:39:26,311] Trial 81 finished with value: 0.8654602419682405 and parameters: {'C_coef': 5.301840336172956, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.12381660160105, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 5}. Best is trial 38 with value: 0.8683813068030887.
# [I 2025-11-03 16:40:12,407] Trial 82 finished with value: 0.8690236500713311 and parameters: {'C_coef': 5.244485922321054, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.858887342374125, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:41:19,892] Trial 83 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.992225727009522, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.955334202102769, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 5, 'num_dimensoes': 5}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:42:10,559] Trial 84 finished with value: 0.8666343206589489 and parameters: {'C_coef': 5.76247773660545, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.527832581780274, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:43:00,184] Trial 85 finished with value: 0.8636194047592344 and parameters: {'C_coef': 5.732117400087915, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.439187741625126, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:43:58,762] Trial 86 finished with value: 0.8544449183838765 and parameters: {'C_coef': 5.093036173972514, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.80133317990888, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:44:47,105] Trial 87 finished with value: 0.8544449183838765 and parameters: {'C_coef': 5.440839388381976, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.858298341824522, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:45:53,976] Trial 88 finished with value: 0.8544449183838765 and parameters: {'C_coef': 6.083197032038397, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.319284217665423, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:46:36,826] Trial 89 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.713169698736156, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.449410705824747, 'grau_polinomial': 1, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:47:16,242] Trial 90 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.177869443639571, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.931528183837762, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:47:59,810] Trial 91 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.7566160891626, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.60745920879852, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:48:38,215] Trial 92 finished with value: 0.866026048152866 and parameters: {'C_coef': 4.0783544111735255, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.85774911360342, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:49:22,020] Trial 93 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.68430755979207, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.609599592056053, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:50:04,304] Trial 94 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.53816646299687, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.688748462149146, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:50:39,009] Trial 95 finished with value: 0.8441800629610426 and parameters: {'C_coef': 4.774061504111756, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 7.999540952530316, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:51:43,892] Trial 96 finished with value: 0.7921900711450245 and parameters: {'C_coef': 3.793436096580236, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.6095987825560725, 'grau_polinomial': 1, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 3, 'num_dimensoes': 2}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:52:24,613] Trial 97 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.19540185989269, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.292726669740548, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:53:03,853] Trial 98 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.1047530785287165, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.689985227270192, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:53:26,553] Trial 99 finished with value: 0.3033707865168539 and parameters: {'C_coef': 4.234045322362553, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 9.682992099684808, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:54:03,987] Trial 100 finished with value: 0.866026048152866 and parameters: {'C_coef': 3.85971000270066, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.291091858715347, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:54:47,079] Trial 101 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.769432435756488, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.031667662158542, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:55:29,653] Trial 102 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.38341694057233, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.206465054993476, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:56:10,839] Trial 103 finished with value: 0.866026048152866 and parameters: {'C_coef': 4.290651706710551, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.326696910057779, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:56:47,296] Trial 104 finished with value: 0.8660087341716167 and parameters: {'C_coef': 3.5864968364514835, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.676862252787409, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:57:35,157] Trial 105 finished with value: 0.8660087341716167 and parameters: {'C_coef': 5.4064922731872915, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.17790979586315, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:58:16,195] Trial 106 finished with value: 0.8666343206589489 and parameters: {'C_coef': 4.439226570105763, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.835621615771915, 'grau_polinomial': 1, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:58:55,089] Trial 107 finished with value: 0.8660087341716167 and parameters: {'C_coef': 3.98994872638464, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.457543881412246, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 16:59:40,257] Trial 108 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.9021696946584985, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 7.826517042455883, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:00:15,035] Trial 109 finished with value: 0.8436925793269436 and parameters: {'C_coef': 4.418774653560913, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 8.487108569771507, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:01:01,813] Trial 110 finished with value: 0.8544449183838765 and parameters: {'C_coef': 3.5853867326359117, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.743600215191833, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:01:44,444] Trial 111 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.621780517846875, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.22830852245922, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:02:27,273] Trial 112 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.593769690714759, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.313979001925357, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:03:09,405] Trial 113 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.65982065127228, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.41800899222108, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:03:56,187] Trial 114 finished with value: 0.8654004616655342 and parameters: {'C_coef': 5.5159903097847796, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.207519149623515, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:04:40,557] Trial 115 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.884341727735264, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.611268580588332, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:05:19,603] Trial 116 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.002353223670523, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.552342811688048, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:06:03,272] Trial 117 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.931079326440349, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.981807372367552, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:06:46,217] Trial 118 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.908744293596135, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.980799895977247, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:07:52,244] Trial 119 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.003581654692949, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.701489632147, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 2, 'num_dimensoes': 2}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:08:32,536] Trial 120 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.277893787843634, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.582131360779224, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:09:16,475] Trial 121 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.827874700040261, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.957183810078588, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:09:58,101] Trial 122 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.51623169637538, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.780606207141942, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:10:43,377] Trial 123 finished with value: 0.8660087341716167 and parameters: {'C_coef': 5.039582953887489, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.955189984108227, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:11:17,486] Trial 124 finished with value: 0.866026048152866 and parameters: {'C_coef': 3.345087190978843, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.336642063929867, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:12:03,177] Trial 125 finished with value: 0.866026048152866 and parameters: {'C_coef': 5.203593127362197, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.849560070432158, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:12:25,752] Trial 126 finished with value: 0.5296277697570775 and parameters: {'C_coef': 4.547921731280858, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 9.47540810023365, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:13:04,551] Trial 127 finished with value: 0.8544449183838765 and parameters: {'C_coef': 3.916629477747839, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.181201445822863, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:14:07,236] Trial 128 finished with value: 0.8544449183838765 and parameters: {'C_coef': 5.56686215956344, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.626081393581925, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:15:27,976] Trial 129 finished with value: 0.7960656449920217 and parameters: {'C_coef': 6.032083392635986, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.638054879747196, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 3}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:15:55,264] Trial 130 finished with value: 0.8544449183838765 and parameters: {'C_coef': 5.0015580980772265, 'kernel': 'linear', 'fit_hiperplano': 'auto', 'coef0': 9.959445192449357, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': False, 'SFS': True, 'num_atributos': 8, 'num_dimensoes': 7}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:16:39,392] Trial 131 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.824849055271968, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.853550823860544, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# ...
# [I 2025-11-03 17:33:21,286] Trial 157 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.170825016812717, 'kernel': 'linear', 'fit_hiperplano': 'auto', 'coef0': 9.731742239382958, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:34:05,371] Trial 158 finished with value: 0.866026048152866 and parameters: {'C_coef': 4.892217659546226, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.321063562167012, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:34:48,182] Trial 159 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.6788155927469575, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.552292929102975, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:35:01,027] Trial 160 finished with value: 0.837287956389793 and parameters: {'C_coef': 5.305625363274693, 'kernel': 'rbf', 'fit_hiperplano': 'scale', 'coef0': 9.58770992050885, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:35:41,368] Trial 161 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.210810398329196, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.699934497288533, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:36:32,841] Trial 162 finished with value: 0.8666343206589489 and parameters: {'C_coef': 5.9223804414222405, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.53206899226232, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:37:08,508] Trial 163 finished with value: 0.8690236500713311 and parameters: {'C_coef': 3.758356226024682, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.793284348000208, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:38:02,219] Trial 164 finished with value: 0.866026048152866 and parameters: {'C_coef': 6.429851358103414, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.989861053028921, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:38:42,623] Trial 165 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.0878658664792535, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.162109558104582, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:39:24,675] Trial 166 finished with value: 0.8630111322531515 and parameters: {'C_coef': 4.47491833762327, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.864962622360439, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:40:10,624] Trial 167 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.9912019793884586, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.376566873256634, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:40:54,652] Trial 168 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.738430330203854, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.682508408072074, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:41:27,404] Trial 169 finished with value: 0.8439919905297699 and parameters: {'C_coef': 4.27981832078294, 'kernel': 'poly', 'fit_hiperplano': 'scale', 'coef0': 8.315291467389143, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:42:18,323] Trial 170 finished with value: 0.8544449183838765 and parameters: {'C_coef': 3.985913322561436, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 3.151949085674418, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 6, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:42:57,492] Trial 171 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.155941749833782, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.96201655576603, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:43:40,706] Trial 172 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.512270641008876, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.018364874631562, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:44:18,501] Trial 173 finished with value: 0.8690236500713311 and parameters: {'C_coef': 3.944573330550244, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.630795711279251, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:45:04,335] Trial 174 finished with value: 0.8690236500713311 and parameters: {'C_coef': 5.142040948197474, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.171251710084107, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:45:48,382] Trial 175 finished with value: 0.8636194047592344 and parameters: {'C_coef': 4.772156228574876, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.535388450964255, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:46:28,889] Trial 176 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.43097113980781, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.77523306633969, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:47:05,537] Trial 177 finished with value: 0.8690236500713311 and parameters: {'C_coef': 3.6530966203128896, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.373995483376197, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:47:17,105] Trial 178 finished with value: 0.8595968981993224 and parameters: {'C_coef': 4.298305154893991, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.087873292412056, 'grau_polinomial': 2, 'normalizacao': 'minmax', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:48:02,472] Trial 179 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.916330285852299, 'kernel': 'linear', 'fit_hiperplano': 'auto', 'coef0': 9.997273406695241, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': False, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:48:51,770] Trial 180 finished with value: 0.866026048152866 and parameters: {'C_coef': 5.652634946934873, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.076757796348373, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:49:34,905] Trial 181 finished with value: 0.8630111322531515 and parameters: {'C_coef': 4.664237799620877, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.769492043106585, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:50:20,020] Trial 182 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.847997517404306, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.804312886040595, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:51:05,597] Trial 183 finished with value: 0.8690236500713311 and parameters: {'C_coef': 5.075630607770801, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.527081537156217, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:51:44,347] Trial 184 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.135531075870284, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.614402601684711, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:52:31,076] Trial 185 finished with value: 0.8683980635839994 and parameters: {'C_coef': 5.4219745961706485, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.999480408742313, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:53:14,179] Trial 186 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.61414548033605, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.738077322337139, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:53:52,418] Trial 187 finished with value: 0.8660087341716167 and parameters: {'C_coef': 3.837151854807942, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.281997624496054, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:54:36,647] Trial 188 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.892657806083645, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.773828019369322, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:54:50,596] Trial 189 finished with value: 0.6797856309201608 and parameters: {'C_coef': 4.4115906962749625, 'kernel': 'sigmoid', 'fit_hiperplano': 'scale', 'coef0': 1.6665980201431205, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:55:36,535] Trial 190 finished with value: 0.8690236500713311 and parameters: {'C_coef': 5.251400782229483, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.29961842563822, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:56:19,595] Trial 191 finished with value: 0.8666343206589489 and parameters: {'C_coef': 4.557401436444592, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.551733224914743, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:56:59,351] Trial 192 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.129206505625763, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.550702151832304, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:57:41,100] Trial 193 finished with value: 0.866026048152866 and parameters: {'C_coef': 4.5098707751291816, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.77683275443388, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:58:24,828] Trial 194 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.731114553377435, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.472768532387336, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 17:59:29,532] Trial 195 finished with value: 0.8544449183838765 and parameters: {'C_coef': 4.240470713303211, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.999640370656309, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 4, 'num_dimensoes': 4}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 18:00:14,483] Trial 196 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.976197845572278, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 3.5955785272560554, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 18:00:56,226] Trial 197 finished with value: 0.8660087341716167 and parameters: {'C_coef': 4.4315455144955065, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.063771386422841, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 18:01:34,983] Trial 198 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.067685209924762, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 9.368742113848185, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.
# [I 2025-11-03 18:02:18,712] Trial 199 finished with value: 0.8690236500713311 and parameters: {'C_coef': 4.748464947324076, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.871043071118986, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}. Best is trial 82 with value: 0.8690236500713311.

# %%
df_analysis = objeto_de_estudo.trials_dataframe()

df_analysis
# Out:
#      number     value             datetime_start          datetime_complete  \
# 0         0  0.857342 2025-11-03 16:14:53.614241 2025-11-03 16:14:54.272845
# 1         1  0.529628 2025-11-03 16:14:54.328573 2025-11-03 16:15:42.922598
# 2         2  0.802284 2025-11-03 16:15:43.079224 2025-11-03 16:15:44.038928
# 3         3  0.860733 2025-11-03 16:15:44.192109 2025-11-03 16:16:15.561560
# 4         4  0.833373 2025-11-03 16:16:15.628502 2025-11-03 16:16:32.004009
# ..      ...       ...                        ...                        ...
# 195     195  0.854445 2025-11-03 17:58:24.854120 2025-11-03 17:59:29.498621
# 196     196  0.869024 2025-11-03 17:59:29.554086 2025-11-03 18:00:14.403585
# 197     197  0.866009 2025-11-03 18:00:14.505872 2025-11-03 18:00:56.192033
# 198     198  0.869024 2025-11-03 18:00:56.251928 2025-11-03 18:01:34.887177
# 199     199  0.869024 2025-11-03 18:01:35.001680 2025-11-03 18:02:18.668630
#
#                   duration  params_C_coef  params_PCA  params_SFS  \
# 0   0 days 00:00:00.658604       6.303266       False       False
# 1   0 days 00:00:48.594025       4.530419        True        True
# 2   0 days 00:00:00.959704       1.653683        True       False
# 3   0 days 00:00:31.369451       8.538914       False        True
# 4   0 days 00:00:16.375507       6.915972        True       False
# ..                     ...            ...         ...         ...
# 195 0 days 00:01:04.644501       4.240471        True        True
# 196 0 days 00:00:44.849499       4.976198        True        True
# 197 0 days 00:00:41.686161       4.431546        True        True
# 198 0 days 00:00:38.635249       4.067685        True        True
# 199 0 days 00:00:43.666950       4.748465        True        True
#
#      params_coef0 params_fit_hiperplano  params_grau_polinomial params_kernel  \
# 0        1.382933                 scale                       2        linear
# 1        8.694689                 scale                       4       sigmoid
# 2        8.603584                 scale                       2        linear
# 3        1.665079                  auto                       4          poly
# 4        8.663354                  auto                       3          poly
# ..            ...                   ...                     ...           ...
# 195      9.999640                 scale                       2        linear
# 196      3.595579                 scale                       2        linear
# 197      9.063771                 scale                       2        linear
# 198      9.368742                 scale                       2        linear
# 199      8.871043                 scale                       2        linear
#
#     params_normalizacao  params_num_atributos  params_num_dimensoes     state
# 0                minmax                     7                     2  COMPLETE
# 1                minmax                     3                     2  COMPLETE
# 2              standard                     6                     2  COMPLETE
# 3                minmax                     2                     2  COMPLETE
# 4              standard                     6                     5  COMPLETE
# ..                  ...                   ...                   ...       ...
# 195            standard                     4                     4  COMPLETE
# 196            standard                     7                     6  COMPLETE
# 197            standard                     7                     6  COMPLETE
# 198            standard                     7                     6  COMPLETE
# 199            standard                     7                     6  COMPLETE
#
# [200 rows x 16 columns]

# %%
melhor_trial = objeto_de_estudo.best_trial

print(f"Número do melhor trial: {melhor_trial.number}")
print(f"Parâmetros do melhor trial: {melhor_trial.params}")
# Out:
# Número do melhor trial: 82
# Parâmetros do melhor trial: {'C_coef': 5.244485922321054, 'kernel': 'linear', 'fit_hiperplano': 'scale', 'coef0': 8.858887342374125, 'grau_polinomial': 2, 'normalizacao': 'standard', 'PCA': True, 'SFS': True, 'num_atributos': 7, 'num_dimensoes': 6}

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] Documentação do optuna. Acesso em: 31/10/2025. Disponível em: https://optuna.readthedocs.io/en/stable/
#
# [2] Sperat, Walter. *Using optuna with sklearn the right way*. Acesso em 31/10/2025. Disponível em: https://medium.com/@walter_sperat/using-optuna-with-sklearn-the-right-way-part-1-6b4ad0ab2451
#
# [3] Página do Support Vector Machine no scikit-learn. Acesso em: 31/10/2025. Disponível em: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
#
# [4] Página do Support Vector Machine em classificação (SVC) na documentação do scikit-learn. Acesso em: 31/10/2025. Disponível em: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC
#
# [5] Helmy, Bahaa; Aibin, Michal. *The C Parameter in Support Vector Machines*. Acesso em: 01/11/2025. Disponível em: https://www.baeldung.com/cs/ml-svm-c-parameter
